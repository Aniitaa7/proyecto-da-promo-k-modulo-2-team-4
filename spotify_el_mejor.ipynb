# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

# %%
url = "https://accounts.spotify.com/api/token"

client_id = "54778a9f1fd7438d9c5710a72d0ca202"

client_secret = "5a150e27569642f99ff3ca122492e811"

# Autenticación

client_credential = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)

sp = spotipy.Spotify(auth_manager=client_credential)

# %%
def datos_filtrados(año, genero):


    datos_filtrados = {"artista": [], "tipo": [], "título_canción": [], "nombre_album": [], "año": [], 'genre': genero}
    for offset in range(0, 1000, 50):
        datos = sp.search(q=f"genre:{genero} year:{año}", type='track', limit=50, offset=offset)
    
        
        for elemento in datos["tracks"]["items"]:
            datos_filtrados["artista"].append(elemento["album"]["artists"][0]["name"])
            datos_filtrados["tipo"].append(elemento['type'])
            datos_filtrados["título_canción"].append(elemento['name'])
            datos_filtrados["nombre_album"].append(elemento["album"]["name"])
            datos_filtrados["año"].append(elemento["album"]["release_date"][0:4])

    return pd.DataFrame(datos_filtrados)

# %%
rock_2021 = datos_filtrados(2021, 'rock')

# %%
rock_2021
# Out:
#              artista   tipo            título_canción  \
# 0           Måneskin  track     I WANNA BE YOUR SLAVE
# 1         Elton John  track   Cold Heart - PNAU Remix
# 2         Elton John  track   Cold Heart - PNAU Remix
# 3           Parmalee  track              Just the Way
# 4       Thomas Rhett  track  What’s Your Country Song
# ..               ...    ...                       ...
# 995  Scotty McCreery  track     How Ya Doin' Up There
# 996           Weezer  track                      Hero
# 997         Daughtry  track            Dearly Beloved
# 998      cleopatrick  track             VICTORIA PARK
# 999        Old Mervs  track               Wait Around
#
#                 nombre_album   año genre
# 0      Teatro d'ira - Vol. I  2021  rock
# 1      The Lockdown Sessions  2021  rock
# 2    Cold Heart (PNAU Remix)  2021  rock
# 3                    For You  2021  rock
# 4     Country Again (Side A)  2021  rock
# ..                       ...   ...   ...
# 995               Same Truck  2021  rock
# 996               Van Weezer  2021  rock
# 997           Dearly Beloved  2021  rock
# 998                   BUMMER  2021  rock
# 999              Wait Around  2021  rock
#
# [1000 rows x 6 columns]

# %%
rock_2022 = datos_filtrados(2022, 'rock')

rock_2022
# Out:
#              artista   tipo                           título_canción  \
# 0         Royel Otis  track                     Oysters In My Pocket
# 1    Imagine Dragons  track                                    Bones
# 2          Jon Pardi  track                       Your Heart Or Mine
# 3        OneRepublic  track                          I Ain't Worried
# 4      Cole Swindell  track             She Had Me At Heads Carolina
# ..               ...    ...                                      ...
# 995    Karma To Burn  track                              Twenty Nine
# 996      Simple Plan  track  Wake Me Up (When This Nightmare’s Over)
# 997       Papa Roach  track                                     Liar
# 998        Chat Pile  track                           Slaughterhouse
# 999     Broken Bells  track                          Love On The Run
#
#                                           nombre_album   año genre
# 0                                 Oysters In My Pocket  2022  rock
# 1                                 Mercury - Acts 1 & 2  2022  rock
# 2                                   Mr. Saturday Night  2022  rock
# 3    I Ain’t Worried (Music From The Motion Picture...  2022  rock
# 4                                           Stereotype  2022  rock
# ..                                                 ...   ...   ...
# 995                           Wild Wonderful Purgatory  2022  rock
# 996                               Harder Than It Looks  2022  rock
# 997                                           Ego Trip  2022  rock
# 998                                      God's Country  2022  rock
# 999                                      INTO THE BLUE  2022  rock
#
# [1000 rows x 6 columns]

# %%
pop_2021 = datos_filtrados(2021, 'pop')

pop_2021
# Out:
#             artista   tipo       título_canción           nombre_album   año  \
# 0    PinkPantheress  track                 Pain        to hell with it  2021
# 1        Tory Lanez  track     The Color Violet          Alone At Prom  2021
# 2          Eyedress  track  Something About You       Mulholland Drive  2021
# 3           Jordana  track   Better in the Dark          Summer's Over  2021
# 4        Tate McRae  track   you broke me first    TOO YOUNG TO BE SAD  2021
# ..              ...    ...                  ...                    ...   ...
# 995         Britton  track   To My Younger Self     To My Younger Self  2021
# 996        (G)I-DLE  track                 HWAA                 I burn  2021
# 997          Morray  track       Bad Situations         Bad Situations  2021
# 998           ATEEZ  track           Turbulence  ZERO : FEVER EPILOGUE  2021
# 999    Lana Del Rey  track  Wildflower Wildfire         Blue Banisters  2021
#
#     genre
# 0     pop
# 1     pop
# 2     pop
# 3     pop
# 4     pop
# ..    ...
# 995   pop
# 996   pop
# 997   pop
# 998   pop
# 999   pop
#
# [1000 rows x 6 columns]

# %%
pop_2022 = datos_filtrados(2022, 'pop')

pop_2022
# Out:
#                                         artista   tipo      título_canción  \
# 0                                    Noah Kahan  track        Stick Season
# 1                                           Djo  track    End of Beginning
# 2                             Sabrina Carpenter  track            Nonsense
# 3                                           SZA  track              Snooze
# 4                                          d4vd  track   Romantic Homicide
# ..                                          ...    ...                 ...
# 995                                    Amos Lee  track       Worry No More
# 996                                    Lil Durk  track  Computer Murderers
# 997  ELVIS (Original Motion Picture Soundtrack)  track               Vegas
# 998                               Alexandra Kay  track    Backroad Therapy
# 999                                 Luke Grimes  track    No Horse To Ride
#
#                                    nombre_album   año genre
# 0                                  Stick Season  2022   pop
# 1                                        DECIDE  2022   pop
# 2                           emails i can't send  2022   pop
# 3                                           SOS  2022   pop
# 4                             Romantic Homicide  2022   pop
# ..                                          ...   ...   ...
# 995                                   Dreamland  2022   pop
# 996                             7220 (Reloaded)  2022   pop
# 997  ELVIS (Original Motion Picture Soundtrack)  2022   pop
# 998                            Backroad Therapy  2022   pop
# 999                            No Horse To Ride  2022   pop
#
# [1000 rows x 6 columns]

# %%
indie_2021 = datos_filtrados(2021, 'indie')

indie_2021
# Out:
#                 artista   tipo         título_canción  \
# 0            Surf Curse  track                 Freaks
# 1              Eyedress  track    Something About You
# 2               Jordana  track     Better in the Dark
# 3                Cafuné  track                 Tek It
# 4    The Rare Occasions  track                 Notion
# ..                  ...    ...                    ...
# 995              JUDAH.  track           Just Because
# 996              Grimes  track  Violence - REZZ Remix
# 997            CHVRCHES  track        Death Stranding
# 998           Part Time  track            Night Drive
# 999             Nascent  track              On My Own
#
#                          nombre_album   año  genre
# 0                              Freaks  2021  indie
# 1                    Mulholland Drive  2021  indie
# 2                       Summer's Over  2021  indie
# 3                             Running  2021  indie
# 4                              Notion  2021  indie
# ..                                ...   ...    ...
# 995                                 7  2021  indie
# 996  Miss Anthropocene (Rave Edition)  2021  indie
# 997             In Search Of Darkness  2021  indie
# 998                            P.D.A.  2021  indie
# 999   Minus The Bullshit Life's Great  2021  indie
#
# [1000 rows x 6 columns]

# %%
indie_2022 = datos_filtrados(2022, 'indie')

indie_2022
# Out:
#               artista   tipo    título_canción         nombre_album   año  \
# 0          Noah Kahan  track      Stick Season         Stick Season  2022
# 1                 Djo  track  End of Beginning               DECIDE  2022
# 2          Noah Kahan  track       All My Love         Stick Season  2022
# 3     Suki Waterhouse  track      Good Looking         Good Looking  2022
# 4         beabadoobee  track  the perfect pair             Beatopia  2022
# ..                ...    ...               ...                  ...   ...
# 995       Kenny Beats  track             Still                LOUIE  2022
# 996      Flying Lotus  track          The Room             The Room  2022
# 997          Nu Genea  track          Marechià     Bar Mediterraneo  2022
# 998     Alec Benjamin  track         Hipocrite       (Un)Commentary  2022
# 999  Ricky Montgomery  track       Talk to You  It's 2016 Somewhere  2022
#
#      genre
# 0    indie
# 1    indie
# 2    indie
# 3    indie
# 4    indie
# ..     ...
# 995  indie
# 996  indie
# 997  indie
# 998  indie
# 999  indie
#
# [1000 rows x 6 columns]

# %%
rap_2021 = datos_filtrados(2021, 'rap')

rap_2021
# Out:
#            artista   tipo                                     título_canción  \
# 0       Tory Lanez  track                                   The Color Violet
# 1    Sleepy Hallow  track                                               2055
# 2        Baby Keem  track                  family ties (with Kendrick Lamar)
# 3        Lil Tecca  track                                          LOT OF ME
# 4           Polo G  track                                            RAPSTAR
# ..             ...    ...                                                ...
# 995    Lil God Dan  track                                             Fresno
# 996      Lil Tecca  track                               ABOUT YOU (with NAV)
# 997    Roddy Ricch  track                                           thailand
# 998           Yeat  track                                         Talk 2 God
# 999       BRS Kash  track  Throat Baby (Go Baby) (with DaBaby & City Girl...
#
#             nombre_album   año genre
# 0          Alone At Prom  2021   rap
# 1           Still Sleep?  2021   rap
# 2       The Melodic Blue  2021   rap
# 3    We Love You Tecca 2  2021   rap
# 4           Hall of Fame  2021   rap
# ..                   ...   ...   ...
# 995               Fresno  2021   rap
# 996  We Love You Tecca 2  2021   rap
# 997       LIVE LIFE FAST  2021   rap
# 998                   4L  2021   rap
# 999            Kash Only  2021   rap
#
# [1000 rows x 6 columns]

# %%
rap_2022 = datos_filtrados(2022, 'rap')

rap_2022
# Out:
#              artista   tipo                        título_canción  \
# 0                SZA  track                                Snooze
# 1                SZA  track                             Kill Bill
# 2             Future  track       WAIT FOR U (feat. Drake & Tems)
# 3             Future  track                     PUFFIN ON ZOOTIEZ
# 4           Lil Durk  track  Broadway Girls (feat. Morgan Wallen)
# ..               ...    ...                                   ...
# 995  Black Eyed Peas  track                       DON'T YOU WORRY
# 996             P-Lo  track               Good (feat. Larry June)
# 997           Future  track                           GOLD STACKS
# 998    Freddie Dredd  track                                 Greed
# 999         Flo Rida  track  No Bad Days (featuring Jimmie Allen)
#
#                              nombre_album   año genre
# 0                                     SOS  2022   rap
# 1                                     SOS  2022   rap
# 2                       I NEVER LIKED YOU  2022   rap
# 3                       I NEVER LIKED YOU  2022   rap
# 4                         7220 (Reloaded)  2022   rap
# ..                                    ...   ...   ...
# 995                             ELEVATION  2022   rap
# 996                                STUNNA  2022   rap
# 997                     I NEVER LIKED YOU  2022   rap
# 998                     Freddie's Inferno  2022   rap
# 999  No Bad Days (featuring Jimmie Allen)  2022   rap
#
# [1000 rows x 6 columns]

# %%
df_concatenado = pd.concat([rock_2021, rock_2022, pop_2022, pop_2021, indie_2021, indie_2022, rap_2021, rap_2022], axis=0, ignore_index=True)

# %%
df_concatenado
# Out:
#               artista   tipo                        título_canción  \
# 0            Måneskin  track                 I WANNA BE YOUR SLAVE
# 1          Elton John  track               Cold Heart - PNAU Remix
# 2          Elton John  track               Cold Heart - PNAU Remix
# 3            Parmalee  track                          Just the Way
# 4        Thomas Rhett  track              What’s Your Country Song
# ...               ...    ...                                   ...
# 7995  Black Eyed Peas  track                       DON'T YOU WORRY
# 7996             P-Lo  track               Good (feat. Larry June)
# 7997           Future  track                           GOLD STACKS
# 7998    Freddie Dredd  track                                 Greed
# 7999         Flo Rida  track  No Bad Days (featuring Jimmie Allen)
#
#                               nombre_album   año genre
# 0                    Teatro d'ira - Vol. I  2021  rock
# 1                    The Lockdown Sessions  2021  rock
# 2                  Cold Heart (PNAU Remix)  2021  rock
# 3                                  For You  2021  rock
# 4                   Country Again (Side A)  2021  rock
# ...                                    ...   ...   ...
# 7995                             ELEVATION  2022   rap
# 7996                                STUNNA  2022   rap
# 7997                     I NEVER LIKED YOU  2022   rap
# 7998                     Freddie's Inferno  2022   rap
# 7999  No Bad Days (featuring Jimmie Allen)  2022   rap
#
# [8000 rows x 6 columns]

# %%
df_concatenado.to_csv('df_concatenado.csv', index=False)

# %%
df_spotify = pd.read_csv('df_concatenado.csv')

# %%
lista_artistas = df_spotify['artista'].tolist()

lista_artistas

# %%
set_artistas = set(lista_artistas)

len(set_artistas)
# Out:
# 1899
