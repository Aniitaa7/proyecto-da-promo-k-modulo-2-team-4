# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

# %%
url = "https://accounts.spotify.com/api/token"

client_id = "54778a9f1fd7438d9c5710a72d0ca202"

client_secret = "5a150e27569642f99ff3ca122492e811"

# Autenticación

client_credential = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)

sp = spotipy.Spotify(auth_manager=client_credential)

# %%
def datos_filtrados(año, genero):


    datos_filtrados = {"artista": [], "tipo": [], "título_canción": [], "nombre_album": [], "año": [], 'genre': genero}
    for offset in range(0, 1000, 50):
        datos = sp.search(q=f"genre:{genero} year:{año}", type='track', limit=50, offset=offset)
    
        
        for elemento in datos["tracks"]["items"]:
            datos_filtrados["artista"].append(elemento["album"]["artists"][0]["name"])
            datos_filtrados["tipo"].append(elemento['type'])
            datos_filtrados["título_canción"].append(elemento['name'])
            datos_filtrados["nombre_album"].append(elemento["album"]["name"])
            datos_filtrados["año"].append(elemento["album"]["release_date"][0:4])

    return pd.DataFrame(datos_filtrados)

# %%
rock_2021 = datos_filtrados(2021, 'rock')

# %%
rock_2021
# Out:
#                  artista   tipo            título_canción  \
# 0               Måneskin  track     I WANNA BE YOUR SLAVE
# 1             Elton John  track   Cold Heart - PNAU Remix
# 2             Elton John  track   Cold Heart - PNAU Remix
# 3               Parmalee  track              Just the Way
# 4           Thomas Rhett  track  What’s Your Country Song
# ..                   ...    ...                       ...
# 995               Weezer  track                      Hero
# 996             Daughtry  track       Break Into My Heart
# 997  Nothing But Thieves  track             Miracle, Baby
# 998          cleopatrick  track             VICTORIA PARK
# 999            Old Mervs  track               Wait Around
#
#                            nombre_album   año genre
# 0                 Teatro d'ira - Vol. I  2021  rock
# 1                 The Lockdown Sessions  2021  rock
# 2               Cold Heart (PNAU Remix)  2021  rock
# 3                               For You  2021  rock
# 4                Country Again (Side A)  2021  rock
# ..                                  ...   ...   ...
# 995                          Van Weezer  2021  rock
# 996                      Dearly Beloved  2021  rock
# 997  Moral Panic (The Complete Edition)  2021  rock
# 998                              BUMMER  2021  rock
# 999                         Wait Around  2021  rock
#
# [1000 rows x 6 columns]

# %%
rock_2022 = datos_filtrados(2022, 'rock')

rock_2022
# Out:
#                artista   tipo                título_canción  \
# 0           Royel Otis  track          Oysters In My Pocket
# 1      Imagine Dragons  track                         Bones
# 2            Jon Pardi  track            Your Heart Or Mine
# 3          OneRepublic  track               I Ain't Worried
# 4        Cole Swindell  track  She Had Me At Heads Carolina
# ..                 ...    ...                           ...
# 995     Fit For A King  track                Eyes Roll Back
# 996      Karma To Burn  track                   Twenty Nine
# 997     The Summer Set  track                     Teenagers
# 998  The Hip Abduction  track                        Always
# 999         Papa Roach  track                          Liar
#
#                                           nombre_album   año genre
# 0                                 Oysters In My Pocket  2022  rock
# 1                                 Mercury - Acts 1 & 2  2022  rock
# 2                                   Mr. Saturday Night  2022  rock
# 3    I Ain’t Worried (Music From The Motion Picture...  2022  rock
# 4                                           Stereotype  2022  rock
# ..                                                 ...   ...   ...
# 995                                 The Hell We Create  2022  rock
# 996                           Wild Wonderful Purgatory  2022  rock
# 997                                            Blossom  2022  rock
# 998                                             Always  2022  rock
# 999                                           Ego Trip  2022  rock
#
# [1000 rows x 6 columns]

# %%
pop_2021 = datos_filtrados(2021, 'pop')

pop_2021
# Out:
#             artista   tipo                               título_canción  \
# 0    PinkPantheress  track                                         Pain
# 1        Tory Lanez  track                             The Color Violet
# 2          Eyedress  track                          Something About You
# 3           Jordana  track                           Better in the Dark
# 4        Tate McRae  track                           you broke me first
# ..              ...    ...                                          ...
# 995          Alesso  track              Chasing Stars (feat. James Bay)
# 996         Britton  track                           To My Younger Self
# 997       DJ Khaled  track  LET IT GO (feat. Justin Bieber & 21 Savage)
# 998        (G)I-DLE  track                                         HWAA
# 999    Lana Del Rey  track                          Wildflower Wildfire
#
#                         nombre_album   año genre
# 0                    to hell with it  2021   pop
# 1                      Alone At Prom  2021   pop
# 2                   Mulholland Drive  2021   pop
# 3                      Summer's Over  2021   pop
# 4                TOO YOUNG TO BE SAD  2021   pop
# ..                               ...   ...   ...
# 995  Chasing Stars (feat. James Bay)  2021   pop
# 996               To My Younger Self  2021   pop
# 997                    KHALED KHALED  2021   pop
# 998                           I burn  2021   pop
# 999                   Blue Banisters  2021   pop
#
# [1000 rows x 6 columns]

# %%
pop_2022 = datos_filtrados(2022, 'pop')

pop_2022
# Out:
#                                         artista   tipo     título_canción  \
# 0                                    Noah Kahan  track       Stick Season
# 1                                           Djo  track   End of Beginning
# 2                             Sabrina Carpenter  track           Nonsense
# 3                                           SZA  track             Snooze
# 4                                          d4vd  track  Romantic Homicide
# ..                                          ...    ...                ...
# 995                                      Deorro  track       Yo Las Pongo
# 996  ELVIS (Original Motion Picture Soundtrack)  track              Vegas
# 997                                    Amos Lee  track      Worry No More
# 998                               Alexandra Kay  track   Backroad Therapy
# 999                           charlieonnafriday  track   Colorado Boulder
#
#                                    nombre_album   año genre
# 0                                  Stick Season  2022   pop
# 1                                        DECIDE  2022   pop
# 2                           emails i can't send  2022   pop
# 3                                           SOS  2022   pop
# 4                             Romantic Homicide  2022   pop
# ..                                          ...   ...   ...
# 995                                Yo Las Pongo  2022   pop
# 996  ELVIS (Original Motion Picture Soundtrack)  2022   pop
# 997                                   Dreamland  2022   pop
# 998                            Backroad Therapy  2022   pop
# 999                                  ONNAFRIDAY  2022   pop
#
# [1000 rows x 6 columns]

# %%
indie_2021 = datos_filtrados(2021, 'indie')

indie_2021
# Out:
#                   artista   tipo         título_canción  \
# 0              Surf Curse  track                 Freaks
# 1                Eyedress  track    Something About You
# 2                 Jordana  track     Better in the Dark
# 3                  Cafuné  track                 Tek It
# 4      The Rare Occasions  track                 Notion
# ..                    ...    ...                    ...
# 995                Grimes  track  Violence - REZZ Remix
# 996              CHVRCHES  track        Death Stranding
# 997          Julien Baker  track               Hardline
# 998        John R. Miller  track   Shenandoah Shakedown
# 999  Strawberry Milk Cult  track             Polarbear!
#
#                          nombre_album   año  genre
# 0                              Freaks  2021  indie
# 1                    Mulholland Drive  2021  indie
# 2                       Summer's Over  2021  indie
# 3                             Running  2021  indie
# 4                              Notion  2021  indie
# ..                                ...   ...    ...
# 995  Miss Anthropocene (Rave Edition)  2021  indie
# 996             In Search Of Darkness  2021  indie
# 997                  Little Oblivions  2021  indie
# 998                       Depreciated  2021  indie
# 999                        Polarbear!  2021  indie
#
# [1000 rows x 6 columns]

# %%
indie_2022 = datos_filtrados(2022, 'indie')

indie_2022
# Out:
#              artista   tipo                   título_canción  \
# 0         Noah Kahan  track                     Stick Season
# 1                Djo  track                 End of Beginning
# 2         Noah Kahan  track                      All My Love
# 3    Suki Waterhouse  track                     Good Looking
# 4        beabadoobee  track                 the perfect pair
# ..               ...    ...                              ...
# 995     MJ Lenderman  track  You Have Bought Yourself a Boat
# 996             LÉON  track                           Soaked
# 997         Nu Genea  track                         Marechià
# 998    Alec Benjamin  track                        Hipocrite
# 999      Jean Dawson  track                       BAD FRUIT*
#
#          nombre_album   año  genre
# 0        Stick Season  2022  indie
# 1              DECIDE  2022  indie
# 2        Stick Season  2022  indie
# 3        Good Looking  2022  indie
# 4            Beatopia  2022  indie
# ..                ...   ...    ...
# 995        Boat Songs  2022  indie
# 996           Circles  2022  indie
# 997  Bar Mediterraneo  2022  indie
# 998    (Un)Commentary  2022  indie
# 999        CHAOS NOW*  2022  indie
#
# [1000 rows x 6 columns]

# %%
rap_2021 = datos_filtrados(2021, 'rap')

rap_2021
# Out:
#             artista   tipo                                     título_canción  \
# 0        Tory Lanez  track                                   The Color Violet
# 1     Sleepy Hallow  track                                               2055
# 2         Baby Keem  track                  family ties (with Kendrick Lamar)
# 3         Lil Tecca  track                                          LOT OF ME
# 4            Polo G  track                                            RAPSTAR
# ..              ...    ...                                                ...
# 995       Lil Tecca  track                               ABOUT YOU (with NAV)
# 996     Roddy Ricch  track                                           thailand
# 997  French Montana  track           Handstand (with Doja Cat feat. Saweetie)
# 998        BRS Kash  track  Throat Baby (Go Baby) (with DaBaby & City Girl...
# 999            Yeat  track                                         Talk 2 God
#
#             nombre_album   año genre
# 0          Alone At Prom  2021   rap
# 1           Still Sleep?  2021   rap
# 2       The Melodic Blue  2021   rap
# 3    We Love You Tecca 2  2021   rap
# 4           Hall of Fame  2021   rap
# ..                   ...   ...   ...
# 995  We Love You Tecca 2  2021   rap
# 996       LIVE LIFE FAST  2021   rap
# 997     They Got Amnesia  2021   rap
# 998            Kash Only  2021   rap
# 999                   4L  2021   rap
#
# [1000 rows x 6 columns]

# %%
rap_2022 = datos_filtrados(2022, 'rap')

rap_2022
# Out:
#            artista   tipo                        título_canción  \
# 0              SZA  track                                Snooze
# 1              SZA  track                             Kill Bill
# 2           Future  track       WAIT FOR U (feat. Drake & Tems)
# 3           Future  track                     PUFFIN ON ZOOTIEZ
# 4         Lil Durk  track  Broadway Girls (feat. Morgan Wallen)
# ..             ...    ...                                   ...
# 995    Chris Brown  track             Addicted (feat. Lil Baby)
# 996  Freddie Dredd  track                                 Greed
# 997           P-Lo  track               Good (feat. Larry June)
# 998         Future  track                           GOLD STACKS
# 999       Flo Rida  track  No Bad Days (featuring Jimmie Allen)
#
#                              nombre_album   año genre
# 0                                     SOS  2022   rap
# 1                                     SOS  2022   rap
# 2                       I NEVER LIKED YOU  2022   rap
# 3                       I NEVER LIKED YOU  2022   rap
# 4                         7220 (Reloaded)  2022   rap
# ..                                    ...   ...   ...
# 995                                Breezy  2022   rap
# 996                     Freddie's Inferno  2022   rap
# 997                                STUNNA  2022   rap
# 998                     I NEVER LIKED YOU  2022   rap
# 999  No Bad Days (featuring Jimmie Allen)  2022   rap
#
# [1000 rows x 6 columns]

# %%
df_concatenado = pd.concat([rock_2021, rock_2022, pop_2022, pop_2021, indie_2021, indie_2022, rap_2021, rap_2022], axis=0, ignore_index=True)

# %%
df_concatenado
# Out:
#             artista   tipo                        título_canción  \
# 0          Måneskin  track                 I WANNA BE YOUR SLAVE
# 1        Elton John  track               Cold Heart - PNAU Remix
# 2        Elton John  track               Cold Heart - PNAU Remix
# 3          Parmalee  track                          Just the Way
# 4      Thomas Rhett  track              What’s Your Country Song
# ...             ...    ...                                   ...
# 7995    Chris Brown  track             Addicted (feat. Lil Baby)
# 7996  Freddie Dredd  track                                 Greed
# 7997           P-Lo  track               Good (feat. Larry June)
# 7998         Future  track                           GOLD STACKS
# 7999       Flo Rida  track  No Bad Days (featuring Jimmie Allen)
#
#                               nombre_album   año genre
# 0                    Teatro d'ira - Vol. I  2021  rock
# 1                    The Lockdown Sessions  2021  rock
# 2                  Cold Heart (PNAU Remix)  2021  rock
# 3                                  For You  2021  rock
# 4                   Country Again (Side A)  2021  rock
# ...                                    ...   ...   ...
# 7995                                Breezy  2022   rap
# 7996                     Freddie's Inferno  2022   rap
# 7997                                STUNNA  2022   rap
# 7998                     I NEVER LIKED YOU  2022   rap
# 7999  No Bad Days (featuring Jimmie Allen)  2022   rap
#
# [8000 rows x 6 columns]
