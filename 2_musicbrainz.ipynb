# %%
import requests

import pandas as pd
import json
import csv
import time

# %%
df_lista_artistas = pd.read_csv('lista_artistas_spotify.csv')

artistas = list(df_lista_artistas['0'])

artistas
# Out:
# ['Måneskin',
#  'Elton John',
#  'Parmalee',
#  'OneRepublic',
#  'Thomas Rhett',
#  'Jason Aldean',
#  'Elle King',
#  'Duran Duran',
#  'Imagine Dragons',
#  'We Are Messengers',
#  'Greta Van Fleet',
#  'Sam Hunt',
#  'Simple Plan',
#  'Twenty One Pilots',
#  'Japanese Breakfast',
#  'Crowder',
#  'Phil Wickham',
#  'Jameson Rodgers',
#  'Lake Street Dive',
#  'Goth Babe',
#  'The Neighbourhood',
#  'Ryan Hurd',
#  'Lauren Daigle',
#  'Glass Animals',
#  'Mitchell Tenpenny',
#  'Disney',
#  'Tommy James & The Shondells',
#  'Papa Roach',
#  'The Hip Abduction',
#  'Scotty McCreery',
#  'The Wombats',
#  'Skylar Grey',
#  'Old Dominion',
#  'Mac Powell',
#  'The Elovaters',
#  'Aimer',
#  'THE DRIVER ERA',
#  'No Vacation',
#  'Paul McCartney',
#  'Chase Rice',
#  'DENM',
#  'Saint Motel',
#  'Vance Joy',
#  'MercyMe',
#  'Rob Zombie',
#  'The White Stripes',
#  'Weezer',
#  'Ryan Stevenson',
#  'Florida Georgia Line',
#  'Bee Gees',
#  'Friday Pilots Club',
#  'Surfer Girl',
#  'Logan Mize',
#  'for KING & COUNTRY',
#  'Jimmie Allen',
#  'if i die in mississippi',
#  'Luna Li',
#  'Walker Hayes',
#  'Zac Brown Band',
#  'Volbeat',
#  'Luke Bryan',
#  'Shinsei Kamattechan',
#  'Brandi Carlile',
#  'Jeremy Camp',
#  'Sanctus Real',
#  'Wine Lips',
#  'Milky Chance',
#  'Arcane',
#  'Sam Fender',
#  'Olivia Newton-John',
#  'Josiah and the Bonnevilles',
#  'Dylan Scott',
#  'Houndmouth',
#  'Cole Swindell',
#  'grandson',
#  'Santana',
#  'Nathaniel Rateliff & The Night Sweats',
#  'Maná',
#  'Danny Gokey',
#  'Fruit Bats',
#  'Colorblind',
#  'The Offspring',
#  'YONAKA',
#  'Tyler Booth',
#  'Bring Me The Horizon',
#  'Limp Bizkit',
#  'Los Fabulosos Cadillacs',
#  'Dead Poet Society',
#  'Nickelback',
#  'KALEO',
#  'Casting Crowns',
#  'Hiss Golden Messenger',
#  'Various Artists',
#  'The War On Drugs',
#  'TobyMac',
#  'Los Angeles Negros',
#  'OFFICIAL HIGE DANDISM',
#  'Rhett Walker',
#  'Sohodolls',
#  'Travis Denning',
#  'Tom Morello',
#  'Maston',
#  'Esteman',
#  'Tame Impala',
#  'Passafire',
#  'Rebelution',
#  'Generación 12',
#  'Ben Rector',
#  'Cody Jinks',
#  'Hippo Campus',
#  'Arrested Youth',
#  'Brantley Gilbert',
#  'STARSET',
#  'Robert Plant',
#  'Inner Wave',
#  'RedHook',
#  'YUNGBLUD',
#  'The Rolling Stones',
#  'Bleachers',
#  'Royal Blood',
#  'Ozzy Osbourne',
#  'Little Stranger',
#  'Joey Valence & Brae',
#  'Shane & Shane',
#  'The Blue Stones',
#  'Wolf Alice',
#  'Manchester Orchestra',
#  'We Came As Romans',
#  'NEEDTOBREATHE',
#  'Dirty Heads',
#  'Kairikibear',
#  'Chevelle',
#  'Iron Maiden',
#  'Black Label Society',
#  'K.Flay',
#  'Art Lown',
#  'Petey',
#  'Tyler Rich',
#  'City of the Sun',
#  'Wet Leg',
#  'Badflower',
#  'Newsboys',
#  'Colton Dixon',
#  'Cidergirl',
#  'Billy Idol',
#  'Mammoth WVH',
#  'Adam Jensen',
#  'Fortunate Youth',
#  'All Time Low',
#  'The Who',
#  'Dayglow',
#  'Radiohead',
#  'The Goo Goo Dolls',
#  'Drew Parker',
#  'Mother Mother',
#  'Daughtry',
#  'Kings of Leon',
#  'Rawayana',
#  'The Green',
#  'DICE',
#  'MAN WITH A MISSION',
#  'John Hiatt',
#  '花冷え。',
#  'MJ Lenderman',
#  'PinocchioP',
#  'Queen',
#  'Michael Ray',
#  'James McMurtry',
#  'Dillon Carmichael',
#  'DREAMERS',
#  'Vana Liya',
#  'Jefferson Airplane',
#  'Francesca Battistelli',
#  'HARRY WAS HERE',
#  'Courtney Barnett',
#  'DECO*27',
#  'Zoé',
#  'Old Mervs',
#  'Delta Sleep',
#  'Jane Remover',
#  'Nirvana',
#  'Ghost',
#  'Noah Gundersen',
#  'Foo Fighters',
#  'IDLES',
#  'Iration',
#  'Of Monsters and Men',
#  'Rise Against',
#  'Fleet Foxes',
#  'The Red Pears',
#  'Mastodon',
#  'Fantastic Negrito',
#  'Stick Figure',
#  'feeble little horse',
#  'Brittany Howard',
#  'La Oreja de Van Gogh',
#  'U2',
#  'Spiral Drive',
#  'The Beatles',
#  'AWOLNATION',
#  'Royel Otis',
#  'Feuerschwanz',
#  'Nothing But Thieves',
#  'Sophie Powers',
#  'Maretu',
#  'Ballyhoo!',
#  'Sharon Van Etten',
#  'Des Rocs',
#  'Joe Samba',
#  'Explosions In The Sky',
#  'Walk off the Earth',
#  'poptropicaslutz!',
#  'cleopatrick',
#  'Airways',
#  'cosMo@Bousou-P',
#  'INXS',
#  'ivri',
#  'Two Feet',
#  'Adelitas Way',
#  'LiSA',
#  'The Cold Stares',
#  'Jon Langston',
#  'Britt Nicole',
#  'Part Time',
#  'Snail Mail',
#  'Sufjan Stevens',
#  'Cold War Kids',
#  'Black Country, New Road',
#  'Linkin Park',
#  'Nicholas Britell',
#  'Cultura Profética',
#  'Rancid Eddie',
#  'Chris Tomlin',
#  'Fujifabric',
#  'Local Natives',
#  'Through The Roots',
#  'Green Day',
#  'Korn',
#  'Iron Butterfly',
#  "Guns N' Roses",
#  'Parannoul',
#  'Death Cab for Cutie',
#  'Renee & Jeremy',
#  'Therapie TAXI',
#  'Ray Bull',
#  'Natalia Jiménez',
#  'Twiztid',
#  'lovelytheband',
#  'Johnny Cash',
#  'Jordan Feliz',
#  'Chris Lane',
#  'Mitch Rossell',
#  'Ace of Hearts',
#  'Dorothy',
#  'Fox Academy',
#  'Melendi',
#  'Barry Gibb',
#  'Foreign Air',
#  'Bastille',
#  'Zayde Wølf',
#  'Waxahatchee',
#  'Dirty Honey',
#  'St. Vincent',
#  'Adam Sanders',
#  'Tigercub',
#  'The Killers',
#  'Sleigh Bells',
#  'Quadeca',
#  'Dropkick Murphys',
#  'The Steel Woods',
#  'Soccer Mommy',
#  'Melvins',
#  'Strawberry Launch',
#  'Slightly Stoopid',
#  'The Rions',
#  'Good Morning',
#  'Male Tears',
#  'Modest Mouse',
#  'Black Pistol Fire',
#  'NewDad',
#  'The Score',
#  'Kero Kero Bonito',
#  'Skillet',
#  'Natalia Lafourcade',
#  'Golden Earring',
#  'Hollywood Undead',
#  'The Bones of J.R. Jones',
#  'X Ambassadors',
#  'The Luka State',
#  'Rod Stewart',
#  'Black Stone Cherry',
#  'The Wallflowers',
#  'Diana Ross',
#  'P.O.D.',
#  'David Bisbal',
#  'Kip Moore',
#  'Sensi Trails',
#  'DON BROCO',
#  'Eve',
#  'Exodus',
#  'La Femme',
#  "The B-52's",
#  'alt-J',
#  'The Movement',
#  'Triumph',
#  'Dear Sunday',
#  '✝✝✝ (Crosses)',
#  'Building 429',
#  'amazarashi',
#  'Foster The People',
#  'Neil Young',
#  'The Script',
#  'joan',
#  'The Penguins',
#  'Convictions',
#  'The Terrys',
#  'Micah Tyler',
#  'Hitorie',
#  'Blackberry Smoke',
#  'Flyte',
#  'WALK THE MOON',
#  'The Black Keys',
#  'my little airport',
#  'Iya Terra',
#  'You Me At Six',
#  'The Voidz',
#  'Lin-Manuel Miranda',
#  'Voz Veis',
#  'Gorillaz',
#  'Shannon & The Clams',
#  'ONE OK ROCK',
#  'Arkells',
#  'Tears for the Dying',
#  'The Felice Brothers',
#  'Counting Crows',
#  'Homayoun Shajarian',
#  'Oasis',
#  'Sublime',
#  'Love and Death',
#  'Los Auténticos Decadentes',
#  'Morgan Evans',
#  'The Record Company',
#  'Moon Taxi',
#  'Serú Girán',
#  'Matthew West',
#  'Brett Eldredge',
#  'Bones Owens',
#  'Chris Janson',
#  'Peter, Paul and Mary',
#  'Car Seat Headrest',
#  'Portugal. The Man',
#  'EGOIST',
#  'Egypt Central',
#  'Palaye Royale',
#  'Santiano',
#  'Brothers Osborne',
#  'Saltatio Mortis',
#  'Ries Brothers',
#  'The Cleftones',
#  'Jon Pardi',
#  'The 1975',
#  'House Of Pain',
#  'Dustin Lynch',
#  'Tauren Wells',
#  'Midrift',
#  'Depeche Mode',
#  'Big Thief',
#  'SunKissed Lola',
#  'quannnic',
#  'Three Days Grace',
#  'Eli Young Band',
#  'Rachael Lampa',
#  'Florence + The Machine',
#  'John Debney',
#  'Polyphia',
#  'Hozier',
#  'The Lumineers',
#  'Bear McCreary',
#  'Russell Dickerson',
#  'Whiskey Myers',
#  'Dylan Schneider',
#  'Slipknot',
#  'RADWIMPS',
#  'King Clave',
#  'I AM THEY',
#  'Dominic Fike',
#  'Rend Collective',
#  'Fontaines D.C.',
#  'Alvvays',
#  'Journey',
#  'My Chemical Romance',
#  'Dan Bremnes',
#  'Brandon Heath',
#  'Red Hot Chili Peppers',
#  'Rammstein',
#  'Yeah Yeah Yeahs',
#  'Level 42',
#  'Tropidelic',
#  'Muse',
#  'Metallica',
#  'Arctic Monkeys',
#  'Lady Gaga',
#  'BUMP OF CHICKEN',
#  'Quarters of Change',
#  'Father John Misty',
#  'Coheed and Cambria',
#  'Alex G',
#  'Jerry Lee Lewis',
#  'Highly Suspect',
#  'ELVIS (Original Motion Picture Soundtrack)',
#  'Chandler Moore',
#  'Bad Suns',
#  'Drake White',
#  'Richy Mitch & The Coal Miners',
#  'Arcy Drive',
#  'Palace',
#  'The Unlikely Candidates',
#  'Young the Giant',
#  'Matt Maher',
#  'Pacific Roots',
#  'Insane Clown Posse',
#  'Andy Frasco & The U.N.',
#  'KANA-BOON',
#  'Jesse Roper',
#  'Siddhartha',
#  'TOOL',
#  'The Beths',
#  'Momma',
#  'Bryce Fox',
#  'HoneyWorks',
#  'TK from Ling tosite sigure',
#  'Marcus King',
#  'Stars Go Dim',
#  'Natalie Grant',
#  'Stephen Bishop',
#  'Megadeth',
#  'Barns Courtney',
#  'Tedeschi Trucks Band',
#  'Beach House',
#  'Lee Brice',
#  'Pixies',
#  'The Poles',
#  'Elvis Presley',
#  'Spoon',
#  'Drugdealer',
#  'Rebecca St. James',
#  'Brent Cobb',
#  'Goodbye June',
#  'Mihali',
#  'Jesús Adrián Romero',
#  'The Happy Fits',
#  'HEALTH',
#  'Bonnie Raitt',
#  'The Struts',
#  'Sigur Rós',
#  'coldrain',
#  'Meredith Andrews',
#  'Anıl Emre Daldal',
#  'black midi',
#  'The Ghost Club',
#  'Spacey Jane',
#  'Rojo',
#  'Bomba Estéreo',
#  'MASS OF THE FERMENTING DREGS',
#  'The Del-Vikings',
#  'Austin French',
#  'UNISON SQUARE GARDEN',
#  'Fit For A King',
#  'PELICAN FANCLUB',
#  'Motörhead',
#  'Tom Petty and the Heartbreakers',
#  'Band of Horses',
#  'Phoenix',
#  'Vulfpeck',
#  'Bryan Adams',
#  'Pink Floyd',
#  'The Beaches',
#  'SUPER BEAVER',
#  'ZAQ',
#  'Wheeland Brothers',
#  'Metric',
#  'Thee Oh Sees',
#  'PEOPLE 1',
#  'Sayuri',
#  'Angel Olsen',
#  'Lynyrd Skynyrd',
#  'Rum Jungle',
#  'Skindred',
#  'Little River Band',
#  'Jack White',
#  'Robert Lester Folsom',
#  'Josh Wilson',
#  'LCD Soundsystem',
#  'Beirut',
#  'Willie J Healey',
#  'Foals',
#  'Artikal Sound System',
#  'Franz Ferdinand',
#  'Jamestown Revival',
#  'CMAT',
#  'The National',
#  'Silverstein',
#  'Stevie Nicks',
#  'JAM Project',
#  'They Are Gutting a Body of Water',
#  'Def Leppard',
#  "Melody's Echo Chamber",
#  'Two Door Cinema Club',
#  'aldrch',
#  'Animals As Leaders',
#  'Bruce Springsteen',
#  'Jimmy Eat World',
#  'The Backfires',
#  'Cairokee',
#  '100 gecs',
#  'Silversun Pickups',
#  'Dynazty',
#  'Bandalos Chinos',
#  'MISSIO',
#  'Ward Davis',
#  'Ocean Alley',
#  'MisterWives',
#  'Sidewalk Prophets',
#  'Mary Lou Lord',
#  'Novelbright',
#  'Arcade Fire',
#  'Mrs. GREEN APPLE',
#  'From Ashes to New',
#  'Fitz and The Tantrums',
#  'Wheatus',
#  'Arlie',
#  'Chat Pile',
#  'Steven Curtis Chapman',
#  'Self Deception',
#  'The Smashing Pumpkins',
#  'Bishop Briggs',
#  'Ichika Nito',
#  'Essential Machine',
#  'HIRIE',
#  'Bush',
#  'Caloncho',
#  'David Scarpeta',
#  'Glasslands',
#  'Th3rd Coast Roots',
#  'Vundabar',
#  'Daily J',
#  'Kurt Vile',
#  'Future Islands',
#  'BABYMETAL',
#  'Kiro Akiyama',
#  'Luke Winslow-King',
#  'The Deadbeat Cousins',
#  'Smash Mouth',
#  'High Valley',
#  'Sleep',
#  'Asian Glow',
#  'MY FIRST STORY',
#  'Linda Ronstadt',
#  'isaur',
#  'Tears For Fears',
#  'QUEEN BEE',
#  'The Slaps',
#  'Karma To Burn',
#  'Noah Kahan',
#  'Djo',
#  'Sabrina Carpenter',
#  'SZA',
#  'd4vd',
#  'Josh Meloy',
#  'Harry Styles',
#  'Suki Waterhouse',
#  'Lil Durk',
#  'beabadoobee',
#  'Drake',
#  'Lizzy McAlpine',
#  'JID',
#  'Taylor Swift',
#  'Wyatt Flores',
#  'Billie Eilish',
#  'David Guetta',
#  'ERNEST',
#  'LECADE',
#  'Omar Apollo',
#  'Lainey Wilson',
#  'Meghan Trainor',
#  'Benson Boone',
#  'Tate McRae',
#  'Post Malone',
#  'Cults',
#  'The Weeknd',
#  'JVKE',
#  'Chance Peña',
#  'Conan Gray',
#  'Feid',
#  'Becky G',
#  'Rema',
#  'Hotel Ugly',
#  'Joji',
#  'Dhruv',
#  'Sam Smith',
#  'Riley Green',
#  'Warren Zeiders',
#  'Alok',
#  'Jack Harlow',
#  'Bryan Martin',
#  'NewJeans',
#  'Swedish House Mafia',
#  'Tory Lanez',
#  'Doja Cat',
#  'Beyoncé',
#  'Ozuna',
#  'Sean Paul',
#  'Bizarrap',
#  'Hailey Whitters',
#  'ROSALÍA',
#  'Yuridia',
#  'Ethel Cain',
#  'David Kushner',
#  'Treaty Oak Revival',
#  'Marshmello',
#  'Macabre Plaza',
#  'Riton',
#  'Jin',
#  'Kylie Morgan',
#  'Matt Hansen',
#  'Shaboozey',
#  'Connor Price',
#  'Kenshi Yonezu',
#  'Alesso',
#  'Sadie Jean',
#  'Alec Benjamin',
#  'Imanbek',
#  'Manuel Turizo',
#  'Tyler Hubbard',
#  'mgk',
#  'Pharrell Williams',
#  'Megan Moroney',
#  'Dean Lewis',
#  'Nicki Minaj',
#  'Ray LaMontagne',
#  'James Hype',
#  'Tiësto',
#  'Orion Sun',
#  'PinkPantheress',
#  'Dove Cameron',
#  'Rex Orange County',
#  'Chri$tian Gate$',
#  'charlieonnafriday',
#  'Stray Kids',
#  'Kyle Hume',
#  'Russ',
#  'Cigarettes After Sex',
#  'Lizzo',
#  'Memphis May Fire',
#  'Felix Jaehn',
#  'Ryan Mack',
#  'Nessa Barrett',
#  'Lil Wayne',
#  'Nate Smith',
#  'Emei',
#  'Charlie Puth',
#  'Leith Ross',
#  'LE SSERAFIM',
#  'BTS',
#  'Danny Ocean',
#  'Vwillz',
#  'Chandler Leighton',
#  'BLACKPINK',
#  'Matt Schuster',
#  'Sub Urban',
#  'Nathan Dawe',
#  'Gucci Mane',
#  'MUNA',
#  'Koe Wetzel',
#  'RAYE',
#  'NAYEON',
#  'Mau y Ricky',
#  'Rauw Alejandro',
#  'Genevieve Stokes',
#  'girl in red',
#  'Sebastian Yatra',
#  'IVE',
#  'Paris Paloma',
#  'VOILÀ',
#  'Jeremih',
#  'Shawn Mendes',
#  'Dylan Conrique',
#  'ENHYPEN',
#  'Kid Cudi',
#  'Corey Kent',
#  'Romeo Santos',
#  'Zach Top',
#  'Alicia Keys',
#  'Stephen Dawes',
#  'Jackson Dean',
#  'Megan Thee Stallion',
#  'George Ezra',
#  'Camila Cabello',
#  'Bailey Zimmerman',
#  'DaBaby',
#  'Charli xcx',
#  'Josh Ross',
#  '(G)I-DLE',
#  'Hueston',
#  'Jax Jones',
#  'Lauren Spencer Smith',
#  'Alex Warren',
#  'Jay Webb',
#  'A Day To Remember',
#  'Sarz',
#  'Diddy',
#  'Vince Guaraldi',
#  'Matisse',
#  'Wild Rivers',
#  'AURORA',
#  'Jax',
#  'SEVENTEEN',
#  'Chase McDaniel',
#  'Parker McCollum',
#  'mazie',
#  'Kameron Marlowe',
#  'Stellar',
#  'Tyga',
#  'Kim Petras',
#  'Dreamville',
#  'Kate Bollinger',
#  'Sean Stemaly',
#  'Hailee Steinfeld',
#  'Tom Odell',
#  'TWICE',
#  'Jamie Miller',
#  'salem ilese',
#  'Burna Boy',
#  'Shakira',
#  'Conner Smith',
#  'ATEEZ',
#  'The Red Clay Strays',
#  'Ian Munsick',
#  'Ado',
#  'Diplo',
#  'Piso 21',
#  'MOTO BANDIT',
#  'Sam Barber',
#  'Creepy Nuts',
#  'Nelly',
#  'Tokyo Tea Room',
#  'Stand Atlantic',
#  'Ha*Ash',
#  'TOMORROW X TOGETHER',
#  'Ski Mask The Slump God',
#  'Fujii Kaze',
#  'Muscadine Bloodline',
#  'Izzamuzzic',
#  'Loud Luxury',
#  'Fireboy DML',
#  'Shwayze',
#  'MEDUZA',
#  'Ashley Cooke',
#  'The Maine',
#  'Porter Robinson',
#  'Huey Mack',
#  'NMIXX',
#  'Kidd G',
#  'Anitta',
#  'Río Roma',
#  'Ofenbach',
#  'Chase Matthew',
#  'Punctual',
#  'Cordae',
#  'Kany García',
#  'Jung Kook',
#  'Oxlade',
#  'Only The Family',
#  'Akon',
#  'Maya Hawke',
#  'Lana Del Rey',
#  'imase',
#  'Oliver Heldens',
#  'Suriel Hess',
#  'GRAHAM',
#  'PALASTIC',
#  'Logan Michael',
#  'Searows',
#  'Kevin Gates',
#  'Dawid Podsiadło',
#  'Halsey',
#  'BIBI',
#  'Maggie Rogers',
#  'W&W',
#  'Rihanna',
#  'Jessie Reyez',
#  'B.I',
#  'Gen Hoshino',
#  'j-hope',
#  'Futuristic',
#  'Nicky Youre',
#  'Ella Langley',
#  'Carter Faith',
#  'ILLENIUM',
#  'Shaylen',
#  'P!nk',
#  'Avril Lavigne',
#  'Ed Sheeran',
#  'DJ Khaled',
#  'Khalid',
#  'Zach Hood',
#  'Lykke Li',
#  'Arden Jones',
#  'Jacquees',
#  'The Chainsmokers',
#  'Kygo',
#  'Nic D',
#  'Asake',
#  'Remi Wolf',
#  'Men I Trust',
#  'Lauv',
#  'Pheelz',
#  'Red Velvet',
#  'sammy rash',
#  'Mad Tsai',
#  'John Legend',
#  'aespa',
#  'benny blanco',
#  'Still Woozy',
#  'Ellie Goulding',
#  'TX2',
#  'Loveless',
#  'blackbear',
#  'Jonas Blue',
#  'almost monday',
#  'Flo Rida',
#  'deadmau5',
#  'Phoebe Bridgers',
#  'Justin Bieber',
#  'ROLE MODEL',
#  'Morat',
#  'Andy Grammer',
#  'YG',
#  'elijah woods',
#  'Paul Partohap',
#  'Kyle Clark',
#  'fromis_9',
#  'DJ Noiz',
#  'Rachel Chinouriri',
#  'Julia Cole',
#  'Vansire',
#  'Cooper Alan',
#  'GAMPER & DADONI',
#  'Ricky Montgomery',
#  'Chappell Roan',
#  'Kenia OS',
#  'Sia',
#  'Bayanni',
#  'Ingrid Andress',
#  'Sam Short',
#  'Eyedress',
#  'Pusha T',
#  'Bazzi',
#  'Abby Sage',
#  'Daniel Seavey',
#  'Tove Lo',
#  'Magnolia Park',
#  'Selena Gomez',
#  'Joel Sunny',
#  'Bella Poarch',
#  'Jet Trouble',
#  'Justine Skye',
#  '5 Seconds of Summer',
#  'ITZY',
#  'STAYC',
#  'Ruger',
#  'Captainsparklez',
#  'LO Worship',
#  'Natalie Jane',
#  'Calvin Harris',
#  'MK',
#  'Seven Lions',
#  'Cuco',
#  'FKA twigs',
#  'Sofía Reyes',
#  'Frankie Cosmos',
#  'Graham Barham',
#  'natori',
#  'Zedd',
#  'Martin Garrix',
#  'Will Linley',
#  'ロクデナシ',
#  'quinnie',
#  'Kelly Clarkson',
#  'NCT DREAM',
#  'NOTD',
#  'FLETCHER',
#  'AP Dhillon',
#  'mxmtoon',
#  'TAEYEON',
#  'Jonah Kagen',
#  'Maisie Peters',
#  'Tai Verdes',
#  'The Ballroom Thieves',
#  'King',
#  'The Game',
#  'James Arthur',
#  'Huddy',
#  'Kidsnot$aints.',
#  'David Morris',
#  'XG',
#  'Kungs',
#  'TREASURE',
#  'Drew Green',
#  'Redferrin',
#  'Queen Naija',
#  'Topic',
#  'Avvy Sra',
#  'Dexys Midnight Runners',
#  'SEULGI',
#  'Shae Gill',
#  'Diljit Dosanjh',
#  'Maggie Lindemann',
#  'Audien',
#  'Movements',
#  'Prince Royce',
#  'Jay Chou',
#  'Troy Cartwright',
#  'Sofia Carson',
#  'Grimes',
#  'Jimin',
#  'Aditya Rikhari',
#  'Amos Lee',
#  'Restless Road',
#  'Wizkid',
#  'Bas',
#  'Kali Uchis',
#  'Jordana',
#  'Olivia Rodrigo',
#  'Jelly Roll',
#  'Cody Johnson',
#  '24kGoldn',
#  'Adele',
#  'The Marías',
#  'Faye Webster',
#  'Bruno Mars',
#  'Migos',
#  'Clairo',
#  'Del Water Gap',
#  'Maroon 5',
#  'Colby Acuff',
#  'Matt Maltese',
#  'DJ Snake',
#  'Tems',
#  'Gigi Perez',
#  'Aventura',
#  'Amaarae',
#  'Young Stoner Life',
#  'JP Saxe',
#  'Marc Seguí',
#  'Magdalena Bay',
#  'Chayce Beckham',
#  'Tones And I',
#  'Joyner Lucas',
#  'LISA',
#  'ACRAZE',
#  'Larry Fleet',
#  'D.O.D',
#  'GAYLE',
#  'Regard',
#  'Don Diablo',
#  'LAGOS',
#  'Holding Absence',
#  'Jervis Campbell',
#  'Lost Frequencies',
#  'Nancy Sinatra',
#  'Madison Beer',
#  'Coldplay',
#  'Yebba',
#  'DDG',
#  'Tainy',
#  'Hayden Coffman',
#  'NF',
#  'Troye Sivan',
#  'WILLOW',
#  'Morgan Wade',
#  'Joel Corry',
#  'mike.',
#  'Camilo',
#  'ROSÉ',
#  'Internet Money',
#  'Becky Hill',
#  'Dua Lipa',
#  'Videoclub',
#  'YOASOBI',
#  'Manuel Medrano',
#  'Hot Mulligan',
#  'Jenna Raine',
#  'zzoilo',
#  'Ariana Grande',
#  'wave to earth',
#  'The Paper Kites',
#  'vaultboy',
#  'MARINA',
#  'Jazmine Sullivan',
#  ...]

# %%
info_artistas = {'Nombre':[],'Tipo':[], 'País de Origen':[], 'Área de Origen':[], 'Inicio de actividad':[], 'Fin de actividad':[], 'Fecha nacimiento':[], 'Fecha fallecimiento':[]}

for artista in artistas: 
    time.sleep(1)
    url = f'https://musicbrainz.org/ws/2/artist/?query={artista}&fmt=json'
    datos_artista = requests.get(url)
    datos_artista.status_code
    data = datos_artista.json()

    try:
        nombre_artista = data['artists'][0]['name']
        info_artistas['Nombre'].append(nombre_artista)
    except KeyError:
        info_artistas['Nombre'].append('None')
    except IndexError:
        continue

    try:
        tipo_artista = data['artists'][0]['type']
        info_artistas['Tipo'].append(tipo_artista)
    except (KeyError, ValueError):     
        info_artistas['Tipo'].append('None') 

    try:
        pais_artista = data['artists'][0]['country']
        info_artistas['País de Origen'].append(pais_artista)
    except KeyError:
        info_artistas['País de Origen'].append('None')
    
    try:
        area_artista = data['artists'][0]['begin-area']['name']
        info_artistas['Área de Origen'].append(area_artista)
    except KeyError:
        info_artistas['Área de Origen'].append('None')

     # Si es un grupo pondrá los datos en inicio y fin de actividad y los otros '-'    
    if tipo_artista == 'Group':
        try:
            inicio_actividad = data['artists'][0]['life-span']['begin']
                
            info_artistas['Inicio de actividad'].append(inicio_actividad)
            info_artistas['Fecha nacimiento'].append('-')

            fin_actividad = data['artists'][0]['life-span']['ended'] 

            info_artistas['Fin de actividad'].append(fin_actividad)
            info_artistas['Fecha fallecimiento'].append('-')
                
            
        except (KeyError, ValueError):  
            info_artistas['Inicio de actividad'].append('None')
            info_artistas['Fecha nacimiento'].append('-')
            info_artistas['Fin de actividad'].append('None')
            info_artistas['Fecha fallecimiento'].append('-')                   

        # Si es una persona pondrá los datos en nacimiento y fallecimiento y los otros '-'
    else:
        try:
            inicio_actividad = data['artists'][0]['life-span']['begin']
                
            info_artistas['Inicio de actividad'].append('-')
            info_artistas['Fecha nacimiento'].append(inicio_actividad)

            fin_actividad = data['artists'][0]['life-span']['ended'] 

            info_artistas['Fin de actividad'].append('-')
            info_artistas['Fecha fallecimiento'].append(fin_actividad)
                
            
        except (KeyError, ValueError):  
            info_artistas['Inicio de actividad'].append('-')
            info_artistas['Fecha nacimiento'].append('None')
            info_artistas['Fin de actividad'].append('-')        
            info_artistas['Fecha fallecimiento'].append('None')

info_artistas
# Out:
# {'Nombre': ['Måneskin',
#   'Elton John',
#   'Parmalee',
#   'OneRepublic',
#   'Thomas Rhett',
#   'Jason Aldean',
#   'Elle King',
#   'Duran Duran',
#   'Imagine Dragons',
#   'We Are Messengers',
#   'Greta Van Fleet',
#   'Sam Hunt',
#   'Simple Plan',
#   'twenty one pilots',
#   'Japanese Breakfast',
#   'Crowder',
#   'Phil Wickham',
#   'Jameson Rodgers',
#   'Lake Street Dive',
#   'Goth Babe',
#   'The Neighbourhood',
#   'Ryan Hurd',
#   'Lauren Daigle',
#   'Glass Animals',
#   'Mitchell Tenpenny',
#   '[Disney]',
#   'Tommy James',
#   'Papa Roach',
#   'The Hip Abduction',
#   'Scotty McCreery',
#   'The Wombats',
#   'Skylar Grey',
#   'Old Dominion',
#   'Mac Powell',
#   'The Elovaters',
#   'Aimer',
#   'THE DRIVER ERA',
#   'No Vacation',
#   'Paul McCartney',
#   'Chase Rice',
#   'DENM',
#   'Saint Motel',
#   'Vance Joy',
#   'MercyMe',
#   'Rob Zombie',
#   'The White Stripes',
#   'Weezer',
#   'Ryan Stevenson',
#   'Florida Georgia Line',
#   'Bee Gees',
#   'Friday Pilots Club',
#   'Surfer Girl',
#   'Logan Mize',
#   'for KING & COUNTRY',
#   'Jimmie Allen',
#   'if i die in mississippi',
#   'Luna Li',
#   'Walker Hayes',
#   'Zac Brown Band',
#   'Volbeat',
#   'Luke Bryan',
#   '神聖かまってちゃん',
#   'Brandi Carlile',
#   'Jeremy Camp',
#   'Sanctus Real',
#   'Wine Lips',
#   'Milky Chance',
#   'Arcane',
#   'Sam Fender',
#   'Olivia Newton‐John',
#   'Josiah and the Bonnevilles',
#   'Dylan Scott',
#   'Houndmouth',
#   'Cole Swindell',
#   'grandson',
#   'Santana',
#   'Nathaniel Rateliff',
#   'Maná',
#   'Danny Gokey',
#   'Fruit Bats',
#   'Colorblind',
#   'The Offspring',
#   'Yonaka',
#   'Tyler Booth',
#   'Bring Me the Horizon',
#   'Limp Bizkit',
#   'Los Fabulosos Cadillacs',
#   'Dead Poet Society',
#   'Nickelback',
#   'Kaleo',
#   'Casting Crowns',
#   'Hiss Golden Messenger',
#   'Various Artists',
#   'The War on Drugs',
#   'tobyMac',
#   'Los Ángeles Negros',
#   'Official髭男dism',
#   'Rhett Walker',
#   'Sohodolls',
#   'Travis Denning',
#   'Tom Morello',
#   'Maston',
#   'Esteman',
#   'Tame Impala',
#   'Passafire',
#   'Rebelution',
#   'Generación 12',
#   'Ben Rector',
#   'Cody Jinks',
#   'Hippo Campus',
#   'Arrested Youth',
#   'Brantley Gilbert',
#   'Starset',
#   'Robert Plant',
#   'Inner Wave',
#   'RedHook',
#   'YUNGBLUD',
#   'The Rolling Stones',
#   'Bleachers',
#   'Royal Blood',
#   'Ozzy Osbourne',
#   'Little Stranger',
#   'Joey Valence',
#   'Shane & Shane',
#   'The Blue Stones',
#   'Wolf Alice',
#   'Manchester Orchestra',
#   'We Came as Romans',
#   'NEEDTOBREATHE',
#   'Dirty Heads',
#   'Kairikibear',
#   'Chevelle',
#   'Iron Maiden',
#   'Black Label Society',
#   'K.Flay',
#   'Art Lown',
#   'Petey',
#   'Tyler Rich',
#   'City of the Sun',
#   'Wet Leg',
#   'Badflower',
#   'Newsboys',
#   'Colton Dixon',
#   'サイダーガール',
#   'Billy Idol',
#   'Mammoth WVH',
#   'Adam Jensen',
#   'Fortunate Youth',
#   'All Time Low',
#   'The Who',
#   'Dayglow',
#   'Radiohead',
#   'The Goo Goo Dolls',
#   'Drew Parker',
#   'Mother Mother',
#   'Daughtry',
#   'Kings of Leon',
#   'Rawayana',
#   'The Green Pajamas',
#   'Dice',
#   'MAN WITH A MISSION',
#   'John Hiatt',
#   '花冷え。',
#   'MJ Lenderman',
#   'ピノキオピー',
#   'Queen',
#   'Michael Ray',
#   'James McMurtry',
#   'Dillon Carmichael',
#   'DREAMERS',
#   'Vana Liya',
#   'Jefferson Airplane',
#   'Francesca Battistelli',
#   'Harry Was Here',
#   'Courtney Barnett',
#   'DECO*27',
#   'Zoé',
#   'Old Mervs',
#   'Delta Sleep',
#   'Jane Remover',
#   'Nirvana',
#   'Ghost',
#   'Noah Gundersen',
#   'Foo Fighters',
#   'IDLES',
#   'Iration',
#   'Of Monsters and Men',
#   'Rise Against',
#   'Fleet Foxes',
#   'The Red Pears',
#   'Mastodon',
#   'Fantastic Negrito',
#   'Stick Figure',
#   'feeble little horse',
#   'Brittany Howard',
#   'La Oreja de Van Gogh',
#   'U2',
#   'Spiral Drive',
#   'The Beatles',
#   'AWOLNATION',
#   'Royel Otis',
#   'Feuerschwanz',
#   'Nothing But Thieves',
#   'Sophie Powers',
#   'MARETU',
#   'Ballyhoo!',
#   'Sharon Van Etten',
#   'Des Rocs',
#   'Joe Samba',
#   'Explosions in the Sky',
#   'Walk off the Earth',
#   'poptropicaslutz!',
#   'cleopatrick',
#   'Airways',
#   'cosMo@暴走P',
#   'INXS',
#   'ivri',
#   'Two Feet',
#   'Adelitas Way',
#   'LiSA',
#   'The Cold Stares',
#   'Jon Langston',
#   'Britt Nicole',
#   'Part Time',
#   'Snail Mail',
#   'Sufjan Stevens',
#   'Cold War Kids',
#   'Black Country, New Road',
#   'Linkin Park',
#   'Nicholas Britell',
#   'Cultura Profética',
#   'Rancid',
#   'Chris Tomlin',
#   'フジファブリック',
#   'Local Natives',
#   'Through the Roots',
#   'Green Day',
#   'Korn',
#   'Iron Butterfly',
#   'Guns N’ Roses',
#   '파란노을',
#   'Death Cab for Cutie',
#   'Renee',
#   'Therapie TAXI',
#   'Ray Bull',
#   'Natalia Jiménez',
#   'Twiztid',
#   'lovelytheband',
#   'Johnny Cash',
#   'Jordan Feliz',
#   'Chris Lane',
#   'Mitch Rossell',
#   'Ace of Hearts',
#   'Dorothy',
#   'Fox Academy',
#   'Melendi',
#   'Barry Gibb',
#   'Foreign Air',
#   'Bastille',
#   'Zayde Wølf',
#   'Waxahatchee',
#   'Dirty Honey',
#   'St. Vincent',
#   'Adam Sanders',
#   'Tigercub',
#   'The Killers',
#   'Sleigh Bells',
#   'Quadeca',
#   'Dropkick Murphys',
#   'The Steel Woods',
#   'Soccer Mommy',
#   'Melvins',
#   'Strawberry Launch',
#   'Slightly Stoopid',
#   'The Rions',
#   'Good Morning',
#   'Male Tears',
#   'Modest Mouse',
#   'Black Pistol Fire',
#   'NewDad',
#   'The Score',
#   'Kero Kero Bonito',
#   'Skillet',
#   'Natalia Lafourcade',
#   'Golden Earring',
#   'Hollywood Undead',
#   'The Bones of J.R. Jones',
#   'X Ambassadors',
#   'The Luka State',
#   'Rod Stewart',
#   'Black Stone Cherry',
#   'The Wallflowers',
#   'Diana Ross',
#   'P.O.D.',
#   'David Bisbal',
#   'Kip Moore',
#   'Sensi',
#   'Don Broco',
#   'Eve',
#   'Exodus',
#   'La Femme',
#   'The B‐52s',
#   'alt‐J',
#   'The Movement',
#   'Triumph',
#   'Dear Sunday',
#   '†††',
#   'Building 429',
#   'amazarashi',
#   'Foster the People',
#   'Neil Young',
#   'The Script',
#   'Joan Baez',
#   'The Penguins',
#   'Convictions',
#   'The Terrys',
#   'Micah Tyler',
#   'ヒトリエ',
#   'Blackberry Smoke',
#   'Flyte',
#   'WALK THE MOON',
#   'The Black Keys',
#   'My Little Airport',
#   'Iya Terra',
#   'You Me at Six',
#   'The Voidz',
#   'Lin‐Manuel Miranda',
#   'Voz Veis',
#   'Gorillaz',
#   'Del Shannon',
#   'ONE OK ROCK',
#   'Arkells',
#   'Tears for the Dying',
#   'The Felice Brothers',
#   'Counting Crows',
#   'Homayoun Shajarian',
#   'Oasis',
#   'Sublime',
#   'Love and Death',
#   'Los Auténticos Decadentes',
#   'Morgan Evans',
#   'The Record Company',
#   'Moon Taxi',
#   'Serú Girán',
#   'Matthew West',
#   'Brett Eldredge',
#   'Bones Owens',
#   'Chris Janson',
#   'Peter, Paul and Mary',
#   'Car Seat Headrest',
#   'Portugal. The Man',
#   'EGOIST',
#   'Egypt Central',
#   'Palaye Royale',
#   'Santiano',
#   'Brothers Osborne',
#   'Saltatio Mortis',
#   'Ries Brothers',
#   'The Cleftones',
#   'Jon Pardi',
#   'The 1975',
#   'House of Pain',
#   'Dustin Lynch',
#   'Tauren Wells',
#   'Midrift',
#   'Depeche Mode',
#   'Big Thief',
#   'SunKissed Lola',
#   'quannnic',
#   'Three Days Grace',
#   'Eli Young Band',
#   'Rachael Lampa',
#   'Florence + the Machine',
#   'John Debney',
#   'Polyphia',
#   'Hozier',
#   'The Lumineers',
#   'Bear McCreary',
#   'Russell Dickerson',
#   'Whiskey Myers',
#   'Dylan Schneider',
#   'Slipknot',
#   'RADWIMPS',
#   'King Clave',
#   'I Am They',
#   'Dominic Fike',
#   'Rend Collective',
#   'Fontaines D.C.',
#   'Alvvays',
#   'Journey',
#   'My Chemical Romance',
#   'Dan Bremnes',
#   'Brandon Heath',
#   'Red Hot Chili Peppers',
#   'Rammstein',
#   'Yeah Yeah Yeahs',
#   'Level 42',
#   'Tropidelic',
#   'Muse',
#   'Metallica',
#   'Arctic Monkeys',
#   'Lady Gaga',
#   'BUMP OF CHICKEN',
#   'Quarters of Change',
#   'Father John Misty',
#   'Coheed and Cambria',
#   'Alex G',
#   'Jerry Lee Lewis',
#   'Highly Suspect',
#   'Motion Picture Soundtrack',
#   'Chandler Moore',
#   'Bad Suns',
#   'Drake White',
#   'Richy Mitch and the Coal Miners',
#   'Arcy Drive',
#   'Palace',
#   'The Unlikely Candidates',
#   'Young the Giant',
#   'Matt Maher',
#   'Pacific Roots',
#   'Insane Clown Posse',
#   'Andy Frasco',
#   'KANA-BOON',
#   'Jesse Roper',
#   'Siddhartha',
#   'Tool',
#   'The Beths',
#   'Momma',
#   'Bryce Fox',
#   'HoneyWorks',
#   'TK',
#   'Marcus King',
#   'Stars Go Dim',
#   'Natalie Grant',
#   'Stephen Bishop',
#   'Megadeth',
#   'Barns Courtney',
#   'Tedeschi Trucks Band',
#   'Beach House',
#   'Lee Brice',
#   'Pixies',
#   'The Poles',
#   'Elvis Presley',
#   'Spoon',
#   'Drugdealer',
#   'Rebecca St. James',
#   'Brent Cobb',
#   'Goodbye June',
#   'Mihali',
#   'Jesús Adrián Romero',
#   'The Happy Fits',
#   'HEALTH',
#   'Bonnie Raitt',
#   'The Struts',
#   'Sigur Rós',
#   'coldrain',
#   'Meredith Andrews',
#   'Anile Dahl',
#   'black midi',
#   'The Ghost Club',
#   'Spacey Jane',
#   'Rojo',
#   'Bomba Estéreo',
#   'MASS OF THE FERMENTING DREGS',
#   'The Del‐Vikings',
#   'Austin French',
#   'UNISON SQUARE GARDEN',
#   'Fit for a King',
#   'PELICAN FANCLUB',
#   'Motörhead',
#   'Tom Petty and the Heartbreakers',
#   'Band of Horses',
#   'Nick Phoenix',
#   'Vulfpeck',
#   'Bryan Adams',
#   'Pink Floyd',
#   'The Beaches',
#   'SUPER BEAVER',
#   'ZAQ',
#   'Wheeland Brothers',
#   'Metric',
#   'Osees',
#   'PEOPLE 1',
#   'Sayuri',
#   'Angel Olsen',
#   'Lynyrd Skynyrd',
#   'Rum Jungle',
#   'Skindred',
#   'Little River Band',
#   'Jack White',
#   'Robert Lester Folsom',
#   'Josh Wilson',
#   'LCD Soundsystem',
#   'Beirut',
#   'Willie J Healey',
#   'Foals',
#   'Artikal Sound System',
#   'Franz Ferdinand',
#   'Jamestown Revival',
#   'CMAT',
#   'The National',
#   'Silverstein',
#   'Stevie Nicks',
#   'JAM Project',
#   'They Are Gutting a Body of Water',
#   'Def Leppard',
#   'Melody’s Echo Chamber',
#   'Two Door Cinema Club',
#   'aldrch',
#   'Animals as Leaders',
#   'Bruce Springsteen',
#   'Jimmy Eat World',
#   'The Backfires',
#   'Cairokee',
#   '100 gecs',
#   'Silversun Pickups',
#   'Dynazty',
#   'Bandalos Chinos',
#   'Missio',
#   'Ward Davis',
#   'Ocean Alley',
#   'MisterWives',
#   'Sidewalk Prophets',
#   'Mary Lou Lord',
#   'Novelbright',
#   'Arcade Fire',
#   'Mrs. GREEN APPLE',
#   'From Ashes to New',
#   'Fitz and the Tantrums',
#   'Wheatus',
#   'Arlie',
#   'Chat Pile',
#   'Steven Curtis Chapman',
#   'Self Deception',
#   'The Smashing Pumpkins',
#   'Bishop Briggs',
#   'Ichika Nito',
#   'Essential Machine',
#   'HIRIE',
#   'Bush',
#   'Caloncho',
#   'David Scarpeta',
#   'Glasslands',
#   'Th3rd',
#   'Vundabar',
#   'Daily J',
#   'Kurt Vile',
#   'Future Islands',
#   'BABYMETAL',
#   '秋山黄色',
#   'Luke Winslow‐King',
#   'The Deadbeat Cousins',
#   'Smash Mouth',
#   'High Valley',
#   'Sleep',
#   'Asian Glow',
#   'MY FIRST STORY',
#   'Linda Ronstadt',
#   'isaur',
#   'Tears for Fears',
#   'Queen Bee',
#   'The Slaps',
#   'Karma to Burn',
#   'Noah Kahan',
#   'Djo',
#   'Sabrina Carpenter',
#   'SZA',
#   'd4vd',
#   'Josh Meloy',
#   'Harry Styles',
#   'Suki Waterhouse',
#   'Lil Durk',
#   'beabadoobee',
#   'Drake',
#   'Lizzy McAlpine',
#   'JID',
#   'Taylor Swift',
#   'Wyatt Flores',
#   'Billie Eilish',
#   'David Guetta',
#   'Ernest Tubb',
#   'LECADE',
#   'Omar Apollo',
#   'Lainey Wilson',
#   'Meghan Trainor',
#   'Benson Boone',
#   'Tate McRae',
#   'Post Malone',
#   'Cults',
#   'The Weeknd',
#   'JVKE',
#   'Chance Peña',
#   'Conan Gray',
#   'Feid',
#   'Becky G',
#   'Rema‐Rema',
#   'Hotel Ugly',
#   'Joji',
#   'dhruv',
#   'Sam Smith',
#   'Riley Green',
#   'Warren Zeiders',
#   'Alok',
#   'Jack Harlow',
#   'Bryan Martin',
#   'NewJeans',
#   'Swedish House Mafia',
#   'Tory Lanez',
#   'Doja Cat',
#   'Beyoncé',
#   'Ozuna',
#   'Sean Paul',
#   'Bizarrap',
#   'Hailey Whitters',
#   'ROSALÍA',
#   'Yuridia',
#   'Ethel Cain',
#   'David Kushner',
#   'Treaty Oak Revival',
#   'Marshmello',
#   'Macabre Plaza',
#   'Riton',
#   'Jin Jin',
#   'Kylie Morgan',
#   'Matt Hansen',
#   'Shaboozey',
#   'Connor Price',
#   '米津玄師',
#   'Alesso',
#   'Sadie Jean',
#   'Alec Benjamin',
#   'Imanbek',
#   'Manuel Turizo',
#   'Tyler Hubbard',
#   'mgk',
#   'Pharrell Williams',
#   'Megan Moroney',
#   'Dean Lewis',
#   'Nicki Minaj',
#   'Ray LaMontagne',
#   'James Hype',
#   'Tiësto',
#   'orion sun',
#   'PinkPantheress',
#   'Dove Cameron',
#   'Rex Orange County',
#   'Chri$tian Gate$',
#   'charlieonnafriday',
#   'Stray Kids',
#   'Kyle Hume',
#   'Russ',
#   'Cigarettes After Sex',
#   'Lizzo',
#   'Memphis May Fire',
#   'Felix Jaehn',
#   'Ryan Mack',
#   'Nessa Barrett',
#   'Lil Wayne',
#   'Nate Smith',
#   'emei',
#   'Charlie Puth',
#   'Leith Ross',
#   'LE SSERAFIM',
#   'BTS',
#   'Danny Ocean',
#   'Vwillz',
#   'Chandler Leighton',
#   'BLACKPINK',
#   'Matt Schuster',
#   'Suburban Tribe',
#   'Nathan Dawe',
#   'Gucci Mane',
#   'MUNA',
#   'Koe Wetzel',
#   'RAYE',
#   'NAYEON',
#   'Mau y Ricky',
#   'Rauw Alejandro',
#   'Genevieve Stokes',
#   'girl in red',
#   'Sebastián Yatra',
#   'IVE',
#   'Paris Paloma',
#   'VOILÀ',
#   'Jeremih',
#   'Shawn Mendes',
#   'Dylan Conrique',
#   'ENHYPEN',
#   'Kid Cudi',
#   'Corey Kent',
#   'Romeo Santos',
#   'Zach Top',
#   'Alicia Keys',
#   'Stephen Dawes',
#   'Jackson Dean',
#   'Megan Thee Stallion',
#   'George Ezra',
#   'Camila Cabello',
#   'Bailey Zimmerman',
#   'DaBaby',
#   'Charli xcx',
#   'Josh Ross',
#   '(G)I‐DLE',
#   'Hueston',
#   'Jax Jones',
#   'Lauren Spencer Smith',
#   'Alex Warren',
#   'Jay Webb',
#   'A Day to Remember',
#   'Sarz',
#   'Diddy',
#   'Vince Guaraldi',
#   'Matisse',
#   'Wild Rivers',
#   'AURORA',
#   'Jax Jones',
#   'SEVENTEEN',
#   'Chase McDaniel',
#   'Parker McCollum',
#   'mazie',
#   'Kameron Marlowe',
#   'Stellar*',
#   'Tyga',
#   'Kim Petras',
#   'Dreamville',
#   'Kate Bollinger',
#   'Sean Stemaly',
#   'Hailee Steinfeld',
#   'Tom Odell',
#   'TWICE',
#   'Jamie Miller',
#   'salem ilese',
#   'Burna Boy',
#   'Shakira',
#   'Conner Smith',
#   'ATEEZ',
#   'The Red Clay Strays',
#   'Ian Munsick',
#   'Ado',
#   'Diplo',
#   'Piso 21',
#   'Moto Bandit',
#   'Sam Barber',
#   'Creepy Nuts',
#   'Nelly',
#   'Tokyo Tea Room',
#   'Stand Atlantic',
#   '林ゆうき',
#   'TOMORROW X TOGETHER',
#   'Ski Mask the Slump God',
#   '藤井風',
#   'Muscadine Bloodline',
#   'Izzamuzzic',
#   'Loud Luxury',
#   'Fireboy DML',
#   'Shwayze',
#   'MEDUZA',
#   'Ashley Cooke',
#   'The Maine',
#   'Porter Robinson',
#   'Huey Mack',
#   'NMIXX',
#   'Kidd G',
#   'Anitta',
#   'Río Roma',
#   'Ofenbach',
#   'Chase Matthew',
#   'Punctual',
#   'Cordae',
#   'Kany García',
#   'Jung Kook',
#   'Oxlade',
#   'Only the Family',
#   'Akon',
#   'Maya Hawke',
#   'Lana Del Rey',
#   'imase',
#   'Oliver Heldens',
#   'Suriel Hess',
#   'Graham Preskett',
#   'PALASTIC',
#   'Logan Michael',
#   'Searows',
#   'Kevin Gates',
#   'Dawid Podsiadło',
#   'Halsey',
#   'Bibi Blocksberg',
#   'Maggie Rogers',
#   'Wolfgang Amadeus Mozart',
#   'Rihanna',
#   'Jessie Reyez',
#   'B.I',
#   '星野源',
#   'j‐hope',
#   'Futuristic',
#   'Nicky Youre',
#   'Ella Langley',
#   'Carter Faith',
#   'ILLENIUM',
#   'Shaylen',
#   'P!nk',
#   'Avril Lavigne',
#   'Ed Sheeran',
#   'DJ Khaled',
#   'Khalid',
#   'Zach Hood',
#   'Lykke Li',
#   'Arden Jones',
#   'Jacquees',
#   'The Chainsmokers',
#   'Kygo',
#   'Nic D',
#   'Asake',
#   'Remi Wolf',
#   'Men I Trust',
#   'Lauv',
#   'Pheelz',
#   'Red Velvet',
#   'sammy rash',
#   'Mad Tsai',
#   'John Legend',
#   'aespa',
#   'benny blanco',
#   'Still Woozy',
#   'Ellie Goulding',
#   'TX2',
#   'Patty Loveless',
#   'blackbear',
#   'Jonas Blue',
#   'almost monday',
#   'Flo Rida',
#   'deadmau5',
#   'Phoebe Bridgers',
#   'Justin Bieber',
#   'ROLE MODEL',
#   'Morat',
#   'Andy Grammer',
#   'YG',
#   'elijah woods',
#   'Paul McCartney',
#   'Kyle Clark',
#   'fromis_9',
#   'DJ Noiz',
#   'Rachel Chinouriri',
#   'Julia Cole',
#   'Vansire',
#   'Cooper Alan',
#   'David Gamper',
#   'Ricky Montgomery',
#   'Chappell Roan',
#   'Kenia Os',
#   'Sia',
#   'Bayanni',
#   'Ingrid Andress',
#   'Sam Short',
#   'Eyedress',
#   'Pusha T',
#   'Bazzi',
#   'Abby Sage',
#   'Daniel Seavey',
#   'Tove Lo',
#   'Magnolia Park',
#   'Selena Gomez',
#   'Joel Sunny',
#   'Bella Poarch',
#   'Jet Trouble',
#   'Justine Skye',
#   '5 Seconds of Summer',
#   'ITZY',
#   'STAYC',
#   'Ruger',
#   'Jordan Maron',
#   'WORSHIP',
#   'Natalie Jane',
#   'Calvin Harris',
#   'MK',
#   'Seven Lions',
#   'Cuco',
#   'FKA twigs',
#   'Sofía Reyes',
#   'Frankie Cosmos',
#   'Graham Barham',
#   'Natori Blue',
#   'Zedd',
#   'Martin Garrix',
#   'Will Linley',
#   'ロクデナシ',
#   'quinnie',
#   'Kelly Clarkson',
#   'NCT DREAM',
#   'NOTD',
#   'FLETCHER',
#   'AP Dhillon',
#   'mxmtoon',
#   'TAEYEON',
#   'Jonah Kagen',
#   'Maisie Peters',
#   'Tai Verdes',
#   'The Ballroom Thieves',
#   'Stephen King',
#   'The Game',
#   'James Arthur',
#   'Huddy',
#   'The Aints',
#   'David Morris',
#   'XG',
#   'Kungs',
#   'TREASURE',
#   'Drew Green',
#   'Redferrin',
#   'Queen Naija',
#   'Topic',
#   'Avvy Sra',
#   'Dexys Midnight Runners',
#   'SEULGI',
#   'Shae Gill',
#   'Diljit Dosanjh',
#   'Maggie Lindemann',
#   'Audien',
#   'Movements',
#   'Prince Royce',
#   '周杰倫',
#   'Troy Cartwright',
#   'Sofia Carson',
#   'Grimes',
#   'Jimin',
#   'Aditya Rikhari',
#   'Amos Lee',
#   'Restless Road',
#   'Wizkid',
#   'Johann Sebastian Bach',
#   'Kali Uchis',
#   'Jordana',
#   'Olivia Rodrigo',
#   'Jelly Roll',
#   'Cody Johnson',
#   '24kGoldn',
#   'Adele',
#   'The Marías',
#   'Faye Webster',
#   'Bruno Mars',
#   'Migos',
#   'Clairo',
#   'Del Water Gap',
#   'Maroon 5',
#   'Colby Acuff',
#   'Matt Maltese',
#   'DJ Snake',
#   'Tems',
#   'Gigi Perez',
#   'Aventura',
#   'Amaarae',
#   'Young Stoner Life',
#   'JP Saxe',
#   'Marc Seguí',
#   'Magdalena Bay',
#   'Chayce Beckham',
#   'Tones and I',
#   'Joyner Lucas',
#   'LiSA',
#   'ACRAZE',
#   'Larry Fleet',
#   'D.O.D',
#   'Crystal Gayle',
#   'Regard',
#   'Don Diablo',
#   'Lagos',
#   'Holding Absence',
#   'Jervis Campbell',
#   'Lost Frequencies',
#   'Nancy Sinatra',
#   'Madison Beer',
#   'Coldplay',
#   'YEBBA',
#   'DDG',
#   'Tainy',
#   'Hayden Coffman',
#   'NF',
#   'Troye Sivan',
#   'WILLOW',
#   'Morgan Wade',
#   'Joel Corry',
#   'Mike Oldfield',
#   'Camilo Sesto',
#   'ROSÉ',
#   'Internet Money',
#   'Becky Hill',
#   'Dua Lipa',
#   'Videoclub',
#   'YOASOBI',
#   'Manuel Medrano',
#   'Hot Mulligan',
#   'Jenna Raine',
#   'Zzoilo',
#   'Ariana Grande',
#   'wave to earth',
#   'The Paper Kites',
#   'vaultboy',
#   'MARINA',
#   'Jazmine Sullivan',
#   ...],
#  'Tipo': ['Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'None',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Other',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Other',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'None',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'None',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'None',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'None',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'None',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'None',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'None',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'None',
#   'Group',
#   'None',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'None',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'None',
#   'Person',
#   'None',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'None',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'None',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'None',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Character',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'None',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'None',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'None',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'None',
#   'Person',
#   'Group',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'None',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'None',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'None',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'None',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   'Group',
#   'Group',
#   'Person',
#   'Person',
#   'Person',
#   ...],
#  'País de Origen': ['IT',
#   'GB',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'GB',
#   'US',
#   'US',
#   'US',
#   'US',
#   'CA',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'None',
#   'US',
#   'US',
#   'US',
#   'GB',
#   'US',
#   'US',
#   'US',
#   'US',
#   'None',
#   'US',
#   'GB',
#   'US',
#   'US',
#   'US',
#   'None',
#   'JP',
#   'US',
#   'US',
#   'GB',
#   'US',
#   'US',
#   'US',
#   'AU',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'GB',
#   'US',
#   'None',
#   'US',
#   'US',
#   'US',
#   'None',
#   'CA',
#   'US',
#   'US',
#   'DK',
#   'US',
#   'JP',
#   'US',
#   'US',
#   'US',
#   'None',
#   'DE',
#   'GB',
#   'GB',
#   'AU',
#   'None',
#   'US',
#   'US',
#   'US',
#   'CA',
#   'US',
#   'US',
#   'MX',
#   'US',
#   'US',
#   'DK',
#   'US',
#   'None',
#   'US',
#   'GB',
#   'US',
#   'AR',
#   'None',
#   'CA',
#   'IS',
#   'US',
#   'US',
#   'None',
#   'US',
#   'US',
#   'CL',
#   'JP',
#   'None',
#   'GB',
#   'US',
#   'US',
#   'None',
#   'CO',
#   'AU',
#   'US',
#   'US',
#   'CO',
#   'US',
#   'None',
#   'US',
#   'US',
#   'US',
#   'US',
#   'GB',
#   'None',
#   'AU',
#   'None',
#   'GB',
#   'US',
#   'GB',
#   'None',
#   'None',
#   'None',
#   'US',
#   'CA',
#   'GB',
#   'US',
#   'US',
#   'US',
#   'US',
#   'None',
#   'US',
#   'GB',
#   'US',
#   'US',
#   'None',
#   'US',
#   'US',
#   'US',
#   'GB',
#   'None',
#   'AU',
#   'US',
#   'JP',
#   'GB',
#   'US',
#   'None',
#   'US',
#   'US',
#   'GB',
#   'US',
#   'GB',
#   'US',
#   'None',
#   'CA',
#   'US',
#   'US',
#   'VE',
#   'US',
#   'None',
#   'JP',
#   'US',
#   'JP',
#   'None',
#   'JP',
#   'GB',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'AU',
#   'JP',
#   'MX',
#   'None',
#   'GB',
#   'None',
#   'US',
#   'SE',
#   'US',
#   'US',
#   'GB',
#   'US',
#   'IS',
#   'US',
#   'US',
#   'None',
#   'US',
#   'None',
#   'US',
#   'None',
#   'None',
#   'ES',
#   'IE',
#   'DE',
#   'GB',
#   'US',
#   'None',
#   'DE',
#   'GB',
#   'None',
#   'JP',
#   'US',
#   'US',
#   'US',
#   'None',
#   'US',
#   'CA',
#   'None',
#   'CA',
#   'None',
#   'JP',
#   'AU',
#   'None',
#   'US',
#   'US',
#   'JP',
#   'US',
#   'US',
#   'US',
#   'None',
#   'US',
#   'US',
#   'US',
#   'GB',
#   'US',
#   'US',
#   'PR',
#   'None',
#   'US',
#   'JP',
#   'US',
#   'None',
#   'US',
#   'US',
#   'US',
#   'US',
#   'None',
#   'US',
#   'AR',
#   'None',
#   'US',
#   'ES',
#   'US',
#   'US',
#   'US',
#   'None',
#   'None',
#   'US',
#   'None',
#   'US',
#   'None',
#   'ES',
#   'AU',
#   'US',
#   'GB',
#   'None',
#   'None',
#   'US',
#   'US',
#   'US',
#   'GB',
#   'US',
#   'US',
#   'None',
#   'US',
#   'US',
#   'US',
#   'US',
#   'None',
#   'US',
#   'None',
#   'None',
#   'US',
#   'None',
#   'None',
#   'None',
#   'US',
#   'GB',
#   'US',
#   'MX',
#   'NL',
#   'US',
#   'None',
#   'US',
#   'None',
#   'GB',
#   'US',
#   'US',
#   'US',
#   'US',
#   'ES',
#   'US',
#   'None',
#   'GB',
#   'US',
#   'US',
#   'FR',
#   'US',
#   'GB',
#   'US',
#   'CA',
#   'AU',
#   'US',
#   'US',
#   'JP',
#   'US',
#   'CA',
#   'IE',
#   'US',
#   'US',
#   'None',
#   'None',
#   'US',
#   'JP',
#   'US',
#   'None',
#   'US',
#   'US',
#   'HK',
#   'None',
#   'GB',
#   'US',
#   'US',
#   'VE',
#   'None',
#   'US',
#   'JP',
#   'CA',
#   'None',
#   'US',
#   'US',
#   'IR',
#   'GB',
#   'None',
#   'US',
#   'AR',
#   'AU',
#   'US',
#   'US',
#   'AR',
#   'US',
#   'US',
#   'None',
#   'US',
#   'US',
#   'None',
#   'US',
#   'JP',
#   'US',
#   'US',
#   'DE',
#   'US',
#   'DE',
#   'None',
#   'None',
#   'US',
#   'GB',
#   'US',
#   'US',
#   'US',
#   'None',
#   'GB',
#   'US',
#   'None',
#   'None',
#   'CA',
#   'US',
#   'US',
#   'GB',
#   'US',
#   'US',
#   'IE',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'JP',
#   'AR',
#   'None',
#   'None',
#   'None',
#   'IE',
#   'CA',
#   'US',
#   'US',
#   'CA',
#   'US',
#   'US',
#   'DE',
#   'US',
#   'GB',
#   'US',
#   'GB',
#   'US',
#   'GB',
#   'US',
#   'JP',
#   'None',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'GB',
#   'None',
#   'US',
#   'US',
#   'None',
#   'None',
#   'None',
#   'US',
#   'US',
#   'US',
#   'None',
#   'US',
#   'None',
#   'JP',
#   'CA',
#   'MX',
#   'US',
#   'NZ',
#   'None',
#   'None',
#   'JP',
#   'JP',
#   'US',
#   'None',
#   'US',
#   'US',
#   'US',
#   'GB',
#   'US',
#   'US',
#   'US',
#   'US',
#   'KR',
#   'US',
#   'US',
#   'None',
#   'US',
#   'US',
#   'None',
#   'None',
#   'MX',
#   'None',
#   'US',
#   'US',
#   'GB',
#   'IS',
#   'JP',
#   'US',
#   'SE',
#   'None',
#   'None',
#   'None',
#   'MX',
#   'CO',
#   'JP',
#   'US',
#   'None',
#   'JP',
#   'US',
#   'JP',
#   'GB',
#   'US',
#   'US',
#   'GB',
#   'US',
#   'CA',
#   'None',
#   'CA',
#   'JP',
#   'JP',
#   'None',
#   'CA',
#   'US',
#   'None',
#   'None',
#   'US',
#   'US',
#   'None',
#   'GB',
#   'AU',
#   'US',
#   'US',
#   'US',
#   'US',
#   'None',
#   'None',
#   'GB',
#   'None',
#   'GB',
#   'US',
#   'IE',
#   'US',
#   'CA',
#   'US',
#   'JP',
#   'US',
#   'GB',
#   'FR',
#   'None',
#   'None',
#   'US',
#   'US',
#   'US',
#   'None',
#   'EG',
#   'US',
#   'US',
#   'SE',
#   'AR',
#   'US',
#   'US',
#   'None',
#   'None',
#   'None',
#   'US',
#   'JP',
#   'CA',
#   'JP',
#   'US',
#   'US',
#   'US',
#   'US',
#   'None',
#   'US',
#   'SE',
#   'US',
#   'GB',
#   'JP',
#   'US',
#   'None',
#   'GB',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'NZ',
#   'US',
#   'US',
#   'JP',
#   'JP',
#   'US',
#   'None',
#   'US',
#   'CA',
#   'US',
#   'None',
#   'JP',
#   'US',
#   'US',
#   'GB',
#   'DE',
#   'None',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'None',
#   'None',
#   'None',
#   'US',
#   'None',
#   'CA',
#   'None',
#   'US',
#   'US',
#   'None',
#   'US',
#   'FR',
#   'US',
#   'None',
#   'US',
#   'US',
#   'US',
#   'US',
#   'CA',
#   'US',
#   'US',
#   'CA',
#   'US',
#   'US',
#   'US',
#   'CO',
#   'US',
#   'GB',
#   'None',
#   'US',
#   'None',
#   'GB',
#   'US',
#   'None',
#   'BR',
#   'US',
#   'None',
#   'KR',
#   'SE',
#   'CA',
#   'US',
#   'US',
#   'PR',
#   'JM',
#   'AR',
#   'US',
#   'ES',
#   'MX',
#   'US',
#   'US',
#   'US',
#   'US',
#   'None',
#   'GB',
#   'None',
#   'US',
#   'None',
#   'US',
#   'None',
#   'JP',
#   'SE',
#   'None',
#   'US',
#   'None',
#   'CO',
#   'US',
#   'US',
#   'US',
#   'US',
#   'AU',
#   'US',
#   'US',
#   'GB',
#   'NL',
#   'None',
#   'None',
#   'US',
#   'None',
#   'US',
#   'US',
#   'KR',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'DE',
#   'None',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'CA',
#   'KR',
#   'KR',
#   'US',
#   'None',
#   'None',
#   'KR',
#   'None',
#   'FI',
#   'GB',
#   'US',
#   'US',
#   'US',
#   'GB',
#   'KR',
#   'VE',
#   'PR',
#   'US',
#   'NO',
#   'CO',
#   'KR',
#   'GB',
#   'US',
#   'US',
#   'CA',
#   'None',
#   'KR',
#   'US',
#   'US',
#   'US',
#   'None',
#   'US',
#   'US',
#   'US',
#   'US',
#   'GB',
#   'US',
#   'US',
#   'US',
#   'None',
#   'None',
#   'KR',
#   'None',
#   'GB',
#   'CA',
#   'None',
#   'None',
#   'US',
#   'NG',
#   'US',
#   'US',
#   'MX',
#   'None',
#   'NO',
#   'GB',
#   'KR',
#   'None',
#   'US',
#   'None',
#   'US',
#   'NZ',
#   'US',
#   'US',
#   'US',
#   'US',
#   'None',
#   'US',
#   'GB',
#   'KR',
#   'US',
#   'None',
#   'NG',
#   'CO',
#   'US',
#   'KR',
#   'None',
#   'None',
#   'JP',
#   'US',
#   'CO',
#   'US',
#   'None',
#   'JP',
#   'US',
#   'None',
#   'AU',
#   'JP',
#   'KR',
#   'US',
#   'JP',
#   'None',
#   'KZ',
#   'CA',
#   'None',
#   'US',
#   'IT',
#   'US',
#   'US',
#   'US',
#   'US',
#   'KR',
#   'None',
#   'BR',
#   'MX',
#   'FR',
#   'US',
#   'GB',
#   'US',
#   'PR',
#   'KR',
#   'GB',
#   'None',
#   'SN',
#   'US',
#   'US',
#   'JP',
#   'NL',
#   'US',
#   'GB',
#   'AT',
#   'US',
#   'None',
#   'US',
#   'PL',
#   'US',
#   'DE',
#   'US',
#   'AT',
#   'US',
#   'CA',
#   'KR',
#   'JP',
#   'KR',
#   'US',
#   'US',
#   'None',
#   'US',
#   'US',
#   'US',
#   'US',
#   'CA',
#   'GB',
#   'US',
#   'US',
#   'None',
#   'SE',
#   'None',
#   'US',
#   'US',
#   'NO',
#   'US',
#   'NG',
#   'US',
#   'CA',
#   'US',
#   'None',
#   'KR',
#   'None',
#   'None',
#   'US',
#   'KR',
#   'US',
#   'US',
#   'GB',
#   'None',
#   'US',
#   'US',
#   'GB',
#   'None',
#   'US',
#   'CA',
#   'US',
#   'CA',
#   'US',
#   'CO',
#   'US',
#   'US',
#   'CA',
#   'GB',
#   'None',
#   'KR',
#   'None',
#   'GB',
#   'None',
#   'None',
#   'None',
#   'US',
#   'None',
#   'US',
#   'MX',
#   'AU',
#   'NG',
#   'US',
#   'None',
#   'PH',
#   'US',
#   'US',
#   'None',
#   'US',
#   'SE',
#   'US',
#   'US',
#   'None',
#   'US',
#   'None',
#   'None',
#   'AU',
#   'KR',
#   'KR',
#   'NG',
#   'US',
#   'None',
#   'None',
#   'None',
#   'US',
#   'US',
#   'US',
#   'None',
#   'MX',
#   'US',
#   'None',
#   'None',
#   'DE',
#   'NL',
#   'None',
#   'JP',
#   'None',
#   'US',
#   'KR',
#   'SE',
#   'US',
#   'CA',
#   'US',
#   'KR',
#   'None',
#   'GB',
#   'US',
#   'None',
#   'US',
#   'US',
#   'GB',
#   'US',
#   'None',
#   'None',
#   'KR',
#   'FR',
#   'KR',
#   'US',
#   'None',
#   'US',
#   'DE',
#   'None',
#   'GB',
#   'KR',
#   'PK',
#   'IN',
#   'US',
#   'US',
#   'None',
#   'US',
#   'None',
#   'None',
#   'US',
#   'CA',
#   'KR',
#   'None',
#   'US',
#   'None',
#   'NG',
#   'DE',
#   'US',
#   'None',
#   'US',
#   'None',
#   'US',
#   'US',
#   'GB',
#   'None',
#   'None',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'US',
#   'GB',
#   'FR',
#   'NG',
#   'None',
#   'US',
#   'GH',
#   'None',
#   'CA',
#   'ES',
#   'US',
#   'US',
#   'AU',
#   'US',
#   'JP',
#   'US',
#   'US',
#   'None',
#   'US',
#   'None',
#   'NL',
#   'DE',
#   'GB',
#   'US',
#   'BE',
#   'US',
#   'US',
#   'GB',
#   'US',
#   'None',
#   'PR',
#   'None',
#   'US',
#   'AU',
#   'US',
#   'US',
#   'None',
#   'GB',
#   'ES',
#   'KR',
#   'None',
#   'GB',
#   'None',
#   'FR',
#   'JP',
#   'CO',
#   'None',
#   'None',
#   'ES',
#   'US',
#   'KR',
#   'AU',
#   'None',
#   'None',
#   'US',
#   ...],
#  'Área de Origen': ['Roma',
#   'Pinner',
#   'None',
#   'Colorado Springs',
#   'Valdosta',
#   'Macon',
#   'Los Angeles',
#   'Birmingham',
#   'Las Vegas',
#   'Monaghan',
#   'Frankenmuth',
#   'Cedartown',
#   'Montréal',
#   'Columbus',
#   'Philadelphia',
#   'None',
#   'San Diego',
#   'None',
#   'Boston',
#   'None',
#   'Newbury Park',
#   'Kalamazoo',
#   'Lafayette',
#   'Oxford',
#   'Nashville',
#   'Kansas City',
#   'Dayton',
#   'Vacaville',
#   'None',
#   'None',
#   'Liverpool',
#   'Mazomanie',
#   'Nashville',
#   'Clanton',
#   'Boston',
#   'None',
#   'Los Angeles',
#   'San Francisco',
#   'Walton',
#   'Asheville',
#   'Santa Barbara',
#   'Los Angeles',
#   'Melbourne',
#   'None',
#   'Haverhill',
#   'Detroit',
#   'Los Angeles',
#   'Bonanza',
#   'Nashville',
#   'Redcliffe',
#   'Chicago',
#   'None',
#   'Clearwater',
#   'Nashville',
#   'Milton',
#   'None',
#   'Toronto',
#   'Mobile',
#   'Dahlonega',
#   'Copenhagen',
#   'Leesburg',
#   'Chiba',
#   'Ravensdale',
#   'Lafayette',
#   'Toledo',
#   'None',
#   'Kassel',
#   'None',
#   'North Shields',
#   'Cambridge',
#   'None',
#   'Bastrop',
#   'New Albany',
#   'Glennville',
#   'Englewood',
#   'San Francisco',
#   'Hermann',
#   'Guadalajara',
#   'Milwaukee',
#   'Chicago',
#   'None',
#   'Huntington Beach',
#   'None',
#   'Morehead',
#   'Sheffield',
#   'Jacksonville',
#   'Buenos Aires',
#   'Boston',
#   'Hanna',
#   'Mosfellsbær',
#   'Daytona Beach',
#   'Durham',
#   'None',
#   'Philadelphia',
#   'Fairfax',
#   'None',
#   'Shimane',
#   'None',
#   'None',
#   'Warner Robins',
#   'Manhattan',
#   'None',
#   'Bogotá',
#   'Sydney',
#   'United States',
#   'Isla Vista',
#   'Bogotá',
#   'Oklahoma City',
#   'None',
#   'Minneapolis',
#   'None',
#   'Jefferson',
#   'Columbus',
#   'West Bromwich',
#   'Los Angeles',
#   'Sydney',
#   'Doncaster',
#   'London',
#   'Bergen County',
#   'Worthing',
#   'Aston',
#   'None',
#   'None',
#   'Texas',
#   'Windsor',
#   'London',
#   'Atlanta',
#   'Troy',
#   'Seneca',
#   'Huntington Beach',
#   'None',
#   'Grayslake',
#   'Leyton',
#   'Los Angeles',
#   'Wilmette',
#   'None',
#   'Royal Oak',
#   'Yuba City',
#   'None',
#   'Isle of Wight',
#   'None',
#   'Mooloolaba',
#   'Murfreesboro',
#   'Japan',
#   'Stanmore',
#   'Los Angeles',
#   'None',
#   'None',
#   'Baltimore',
#   'London',
#   'Aledo',
#   'Abingdon-on-Thames',
#   'Buffalo',
#   'None',
#   'Vancouver',
#   'None',
#   'Nashville',
#   'Caracas',
#   'Seattle',
#   'Germany',
#   'Tokyo',
#   'Indianapolis',
#   'Tokyo',
#   'None',
#   'Saitama',
#   'London',
#   'Eustis',
#   'Fort Worth',
#   'Burgin',
#   'Manhattan',
#   'None',
#   'San Francisco',
#   'New York',
#   'United States',
#   'Sydney',
#   'Fukuoka',
#   'Cuernavaca',
#   'None',
#   'None',
#   'Newark',
#   'Aberdeen',
#   'Linköping',
#   'Olympia',
#   'Seattle',
#   'Bristol',
#   'California',
#   'Keflavík',
#   'Chicago',
#   'Seattle',
#   'None',
#   'Atlanta',
#   'Massachusetts',
#   'Duxbury',
#   'Pittsburgh',
#   'Athens',
#   'San Sebastián',
#   'Dublin',
#   'Mannheim',
#   'Liverpool',
#   'Los Angeles',
#   'Sydney',
#   'Erlangen',
#   'Southend-on-Sea',
#   'None',
#   'None',
#   'Aberdeen',
#   'Clinton',
#   'None',
#   'None',
#   'Austin',
#   'Burlington',
#   'None',
#   'Cobourg',
#   'Peterborough',
#   'None',
#   'Sydney',
#   'None',
#   'Manhattan',
#   'Las Vegas',
#   'Seki',
#   'Nashville',
#   'Loganville',
#   'None',
#   'None',
#   'Baltimore',
#   'Detroit',
#   'Fullerton',
#   'Cambridge',
#   'Agoura Hills',
#   'New York',
#   'San Juan',
#   'Albany',
#   'Grand Saline',
#   'None',
#   'Silver Lake',
#   'None',
#   'Berkeley',
#   'Bakersfield',
#   'San Diego',
#   'Los Angeles',
#   'None',
#   'Bellingham',
#   'Argentina',
#   'Paris',
#   'None',
#   'Madrid',
#   'Detroit',
#   'West Hollywood',
#   'Kingsland',
#   'Clovis',
#   'North Carolina',
#   'Chattanooga',
#   'None',
#   'Los Angeles',
#   'None',
#   'Oviedo',
#   'Douglas',
#   'None',
#   'London',
#   'None',
#   'Birmingham',
#   'Los Angeles',
#   'Tulsa',
#   'None',
#   'Brighton',
#   'Las Vegas',
#   'Brooklyn',
#   'Los Angeles',
#   'Quincy',
#   'Nashville',
#   'Zurich',
#   'Montesano',
#   'None',
#   'San Diego',
#   'None',
#   'Melbourne',
#   'None',
#   'Issaquah',
#   'Toronto',
#   'Galway',
#   'New York',
#   'Bromley',
#   'Memphis',
#   'Coatepec',
#   'Den Haag',
#   'Hollywood',
#   'None',
#   'Brooklyn',
#   'Winsford',
#   'Highgate',
#   'Edmonton',
#   'Los Angeles',
#   'Detroit',
#   'San Diego',
#   'Almería',
#   'Tifton',
#   'None',
#   'Bedford',
#   'Philadelphia',
#   'Richmond',
#   'Biarritz',
#   'Athens',
#   'Leeds',
#   'Columbia',
#   'Mississauga',
#   'None',
#   'Los Angeles',
#   'Fayetteville',
#   'Mutsu',
#   'Los Angeles',
#   'Toronto',
#   'Dublin',
#   'Staten Island',
#   'Los Angeles',
#   'None',
#   'None',
#   'Beaumont',
#   'Japan',
#   'Atlanta',
#   'London',
#   'Cincinnati',
#   'Akron',
#   'Hong Kong',
#   'Los Angeles',
#   'Weybridge',
#   'New York',
#   'Manhattan',
#   'Maracaibo',
#   'Essex',
#   'Grand Rapids',
#   'Tokyo',
#   'Hamilton',
#   'None',
#   'Palenville',
#   'Berkeley',
#   'Tehran',
#   'Manchester',
#   'Long Beach',
#   'None',
#   'None',
#   'Newcastle',
#   'Los Angeles',
#   'Vestavia Hills',
#   'Buenos Aires',
#   'Downers Grove',
#   'Paris',
#   'None',
#   'Perryville',
#   'New York',
#   'Leesburg',
#   'Wasilla',
#   'Japan',
#   'Memphis',
#   'Las Vegas',
#   'None',
#   'Anne Arundel County',
#   'Karlsruhe',
#   'Clearwater',
#   'None',
#   'Dixon',
#   'Manchester',
#   'New York',
#   'Tullahoma',
#   'Battle Creek',
#   'None',
#   'Basildon',
#   'Brooklyn',
#   'None',
#   'None',
#   'Norwood',
#   'None',
#   'Ann Arbor',
#   'London',
#   'Glendale',
#   'Plano',
#   'Bray',
#   'Ramsey',
#   'Fort Lauderdale',
#   'Nashville',
#   'Palestine',
#   'Terre Haute',
#   'Des Moines',
#   'Yokohama',
#   'Formosa',
#   'None',
#   'Naples',
#   'Bangor',
#   'Dublin',
#   'Toronto',
#   'San Francisco',
#   'Newark',
#   'Kamloops',
#   'Nashville',
#   'Los Angeles',
#   'Berlin',
#   'New York',
#   'Isle of Wight',
#   'Cleveland',
#   'Teignmouth',
#   'Los Angeles',
#   'High Green',
#   'Upper East Side',
#   'None',
#   'None',
#   'Rockville',
#   'Nyack',
#   'Havertown',
#   'Ferriday',
#   'Massachusetts',
#   'None',
#   'Charleston',
#   'Woodland Hills',
#   'Hokes Bluff',
#   'Colorado Springs',
#   'None',
#   'Louisville',
#   'Keller',
#   'Irvine',
#   'Newfoundland and Labrador',
#   'None',
#   'Delray, Detroit',
#   'California',
#   'Sakai',
#   'Canada',
#   'Guadalajara',
#   'Los Angeles',
#   'Auckland',
#   'None',
#   'None',
#   'None',
#   'Machida',
#   'Greenville',
#   'None',
#   'Seattle',
#   'San Diego',
#   'Los Angeles',
#   'Aylesbury',
#   'Jacksonville',
#   'Baltimore',
#   'Sumter',
#   'Boston',
#   'South Korea',
#   'Tupelo',
#   'Austin',
#   'None',
#   'Sydney',
#   'Ellaville',
#   'Nashville',
#   'None',
#   'Hermosillo',
#   'New Jersey',
#   'Los Angeles',
#   'Burbank',
#   'Derby',
#   'Reykjavík',
#   'Nagoya',
#   'None',
#   'Türkiye',
#   'Croydon',
#   'None',
#   'Perth',
#   'Hermosillo',
#   'Bogotá',
#   'Kobe',
#   'Pittsburgh',
#   'None',
#   'None',
#   'None',
#   'None',
#   'London',
#   'Gainesville',
#   'Seattle',
#   'London',
#   'Ann Arbor',
#   'Kingston',
#   'London',
#   'Toronto',
#   'None',
#   'Aira',
#   'None',
#   'Toronto',
#   'San Francisco',
#   'Japan',
#   'None',
#   'St. Louis',
#   'Jacksonville',
#   'Newcastle',
#   'Newport',
#   'Melbourne',
#   'Detroit',
#   'Georgia',
#   'None',
#   'New York',
#   'Santa Fe',
#   'None',
#   'Oxford',
#   'Delray Beach',
#   'Glasgow',
#   'None',
#   'County Meath',
#   'Brooklyn',
#   'Burlington',
#   'Phoenix',
#   'Japan',
#   'Philadelphia',
#   'Sheffield',
#   'None',
#   'Bangor',
#   'Minneapolis',
#   'Washington, D.C.',
#   'Long Branch',
#   'Mesa',
#   'London',
#   'None',
#   'St. Louis',
#   'Los Angeles',
#   'Stockholm',
#   'Buenos Aires',
#   'Austin',
#   'None',
#   'Sydney',
#   'New York',
#   'Nashville',
#   'Salem',
#   'None',
#   'Montréal',
#   'None',
#   'Lancaster',
#   'Los Angeles',
#   'Northport',
#   'Nashville',
#   'Oklahoma City',
#   'Paducah',
#   'Stockholm',
#   'Chicago',
#   'London',
#   'None',
#   'None',
#   'None',
#   'London',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'New Zealand',
#   'Lansdowne',
#   'Greenville',
#   'Tokyo',
#   'Utsunomiya',
#   'Cadillac',
#   'None',
#   'San Jose',
#   'La Crete',
#   'San Jose',
#   'Seoul',
#   'Shibuya',
#   'Tucson',
#   'Greenville',
#   'Bath',
#   'None',
#   'Chicago',
#   'Morgantown',
#   'Strafford',
#   'Newburyport',
#   'Bucks County',
#   'St. Louis',
#   'Queens',
#   'None',
#   'Redditch',
#   'Hammersmith',
#   'Chicago',
#   'Iloilo City',
#   'Toronto',
#   'Philadelphia',
#   'Atlanta',
#   'West Reading',
#   'None',
#   'Los Angeles',
#   'Paris',
#   'Ellis County',
#   'None',
#   'Hobart',
#   'Baskin',
#   'Nantucket',
#   'Monroe',
#   'Calgary',
#   'Syracuse',
#   'Manhattan',
#   'Scarborough',
#   'Providence',
#   'Tyler',
#   'Lemon Grove',
#   'Medellín',
#   'Inglewood',
#   'London',
#   'None',
#   'Osaka',
#   'India',
#   'London',
#   'Jacksonville',
#   'None',
#   'Goiânia',
#   'Louisville',
#   'None',
#   'Seoul',
#   'Stockholm',
#   'Brampton',
#   'Tarzana',
#   'Houston',
#   'San Juan',
#   'Kingston',
#   'Argentina',
#   'Shueyville',
#   'Sant Esteve Sesrovires',
#   'Hermosillo',
#   'Tallahassee',
#   'None',
#   'None',
#   'Philadelphia',
#   'None',
#   'Newcastle upon Tyne',
#   'None',
#   'None',
#   'California',
#   'Fairfax',
#   'Toronto',
#   'Tokushima',
#   'Stockholm',
#   'Tustin',
#   'Phoenix',
#   'Kazakhstan',
#   'Córdoba',
#   'Monroe',
#   'Houston',
#   'Virginia Beach',
#   'Nashville',
#   'Sydney',
#   'Saint James',
#   'Nashua',
#   'None',
#   'Breda',
#   'None',
#   'Bath',
#   'Bainbridge Island',
#   'Haslemere',
#   'None',
#   'None',
#   'Seoul',
#   'None',
#   'Secaucus',
#   'El Paso',
#   'Detroit',
#   'Denton',
#   'Hamburg',
#   'None',
#   'Atlantic County',
#   'New Orleans',
#   'None',
#   'New Jersey',
#   'Janesville',
#   'None',
#   'Seoul',
#   'Seoul',
#   'Caracas',
#   'None',
#   'Los Angeles',
#   'Seoul',
#   'Illinois',
#   'Finland',
#   'Burton upon Trent',
#   'Bessemer',
#   'Los Angeles',
#   'Pittsburg',
#   'Tooting',
#   'Seoul',
#   'None',
#   'San Juan',
#   'None',
#   'Horten',
#   'Medellín',
#   'Seoul',
#   'Ashbourne',
#   'Los Angeles',
#   'Chicago',
#   'Pickering',
#   'Gilroy',
#   'Seoul',
#   'Cleveland',
#   'None',
#   'The Bronx',
#   'None',
#   'Manhattan',
#   'None',
#   'Odenton',
#   'San Antonio',
#   'Bristol',
#   'Cojímar',
#   'None',
#   'Cleveland',
#   'Cambridge',
#   'None',
#   'Seoul',
#   'None',
#   'London',
#   'Portsmouth',
#   'Carlsbad',
#   'None',
#   'Ocala',
#   'Edo',
#   'Harlem',
#   'San Francisco',
#   'None',
#   'Kingston',
#   'Stavanger',
#   'London',
#   'Seoul',
#   'None',
#   'Conroe',
#   'None',
#   'Kannapolis',
#   'Auckland',
#   'Compton',
#   'Köln',
#   'None',
#   'Charlottesville',
#   'None',
#   'Los Angeles',
#   'Chichester',
#   'Seoul',
#   'Wales',
#   'None',
#   'Port Harcourt',
#   'Barranquilla',
#   'Nashville',
#   'Seoul',
#   'Mobile',
#   'None',
#   'Tokyo',
#   'Tupelo',
#   'None',
#   'Nashville',
#   'None',
#   'None',
#   'Austin',
#   'None',
#   'Sydney',
#   'Kyoto',
#   'Seoul',
#   'Fort Lauderdale',
#   'Satoshō',
#   'None',
#   'None',
#   'London',
#   'Ogun',
#   'Malibu',
#   'Milano',
#   'Parkland',
#   'Tempe',
#   'Chapel Hill',
#   'Morgantown',
#   'Seoul',
#   'None',
#   'Rio de Janeiro',
#   'None',
#   'Paris',
#   'Michigan',
#   'None',
#   'Raleigh',
#   'Toa Baja',
#   'Busan',
#   'Nigeria',
#   'None',
#   'St. Louis',
#   'New York',
#   'Manhattan',
#   'Gifu',
#   'Rotterdam',
#   'None',
#   'None',
#   'None',
#   'United States',
#   'None',
#   'New Orleans',
#   'Dąbrowa Górnicza',
#   'Washington',
#   'None',
#   'Easton',
#   'Salzburg',
#   'Saint Michael',
#   'Toronto',
#   'Cheonan',
#   'Saitama',
#   'Gwangju',
#   'None',
#   'Anaheim',
#   'None',
#   'Davidson',
#   'Chicago',
#   'Chattanooga',
#   'Doylestown',
#   'Belleville',
#   'Halifax',
#   'New Orleans',
#   'Fort Stewart',
#   'None',
#   'Ystad',
#   'None',
#   'Atlanta',
#   'New York',
#   'Singapore',
#   'None',
# ...
#   '-',
#   '1978-11-10',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '1945-11-12',
#   '-',
#   '1941-01-09',
#   '-',
#   '-',
#   '-',
#   '1983-04-19',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '1980-01-16',
#   '-',
#   '-',
#   '1934-12-30',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '1975-05-21',
#   '-',
#   '-',
#   '-',
#   '-',
#   '1985-04-24',
#   '-',
#   '-',
#   '-',
#   '1977-04-25',
#   '1986-03-23',
#   'None',
#   '1986-04-02',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '1985-05-20',
#   '-',
#   '-',
#   '1985-05-14',
#   '1986-04-07',
#   '-',
#   '-',
#   '-',
#   '-',
#   'None',
#   '-',
#   '-',
#   '1985-01-08',
#   '-',
#   '1956-08-18',
#   '-',
#   '1990-03-17',
#   '-',
#   '1979-02-17',
#   '1987-05-07',
#   '-',
#   '1999-10-09',
#   '-',
#   '-',
#   '1944-02-14',
#   '-',
#   '1995-12-30',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '1983-05-11',
#   '1978-07-21',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '1986-03-28',
#   '-',
#   '-',
#   '1981-05-03',
#   '-',
#   '1993-02-03',
#   '1935-09-29',
#   '-',
#   '-',
#   '1995-03-21',
#   '-',
#   '1983-10-03',
#   '-',
#   '-',
#   '1970-12-24',
#   '-',
#   '-',
#   '1974-11-10',
#   '-',
#   '-',
#   'None',
#   '-',
#   '1982-03-20',
#   '1990-08-25',
#   '-',
#   '-',
#   '-',
#   'None',
#   '-',
#   '1982-12-23',
#   '1996-03-11',
#   'None',
#   '1971-12-21',
#   '1951-11-14',
#   '-',
#   '1990-11-17',
#   '-',
#   '-',
#   '1979-06-10',
#   '-',
#   '-',
#   '1935-01-08',
#   '-',
#   '-',
#   '1977-07-26',
#   '1986-08-01',
#   '-',
#   'None',
#   '1965-02-16',
#   '-',
#   '-',
#   '1949-11-08',
#   '-',
#   '-',
#   '-',
#   'None',
#   'None',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '1994-02-13',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '1967',
#   '-',
#   '1959-11-05',
#   '-',
#   '-',
#   '-',
#   '1988-03-16',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '1987-01-22',
#   '-',
#   '-',
#   '-',
#   '-',
#   '1975-07-09',
#   '1955-01-03',
#   '1981-02-26',
#   '-',
#   '-',
#   'None',
#   '-',
#   '-',
#   '-',
#   '-',
#   '1996-02-23',
#   '-',
#   '-',
#   '1948-05-26',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   'None',
#   '-',
#   '1949-09-23',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   'None',
#   '-',
#   '-',
#   '-',
#   '1965-03-01',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '1962-11-21',
#   '-',
#   '-',
#   '1992-07-18',
#   '1994-07-07',
#   '-',
#   'None',
#   '-',
#   'None',
#   'None',
#   '-',
#   '-',
#   '-',
#   '-',
#   '1980-01-03',
#   '-',
#   '-',
#   '1996-03-11',
#   '1983-03-12',
#   '-',
#   '-',
#   '-',
#   '-',
#   '2001-06-14',
#   '-',
#   '1946-07-15',
#   'None',
#   '-',
#   '-',
#   '-',
#   '-',
#   '1997-01-01',
#   '1992-04-24',
#   '1999-05-11',
#   '1989-11-08',
#   '2005-03-28',
#   'None',
#   '1994-02-01',
#   '1992-01-05',
#   '1992-10-19',
#   '2000-06-03',
#   '1986-10-24',
#   '1999-09-21',
#   '1990-10-31',
#   '1989-12-13',
#   'None',
#   '2001-12-18',
#   '1967-11-07',
#   '1914-02-09',
#   'None',
#   '1997-05-20',
#   '1992-05-19',
#   '1993-12-22',
#   '2002-06-25',
#   '2003-07-01',
#   '1995-07-04',
#   '-',
#   '1990-02-16',
#   '2001-03-01',
#   '2000-02-18',
#   '1998-12-05',
#   '1992-08-19',
#   '1997-03-02',
#   '-',
#   '-',
#   '1992-09-18',
#   'None',
#   '1992-05-19',
#   '1988-10-18',
#   'None',
#   '1991-08-26',
#   '1998-03-13',
#   'None',
#   '-',
#   '-',
#   '1992-07-27',
#   '1995-10-21',
#   '1981-09-04',
#   '1992-03-13',
#   '1973-01-09',
#   '1998',
#   '1989-09-09',
#   '1992-09-25',
#   '1986-10-04',
#   '1998-03-24',
#   'None',
#   '-',
#   '1992-05-19',
#   'None',
#   '1978-09',
#   'None',
#   'None',
#   '1985',
#   '1995-05-09',
#   '1994-11-11',
#   '1991-03-10',
#   '1991-07-07',
#   '2002-05-15',
#   '1994-05-28',
#   '2000-10-21',
#   '2000-04-12',
#   '1987-01-31',
#   '1990-04-22',
#   '1973-04-05',
#   '1996-12-16',
#   '1987-10-21',
#   '1982-12-08',
#   '1973-06-18',
#   '1989',
#   '1969-01-17',
#   '1997-02-08',
#   '2001-04-19',
#   '1996-01-15',
#   '1998-05-04',
#   'None',
#   'None',
#   '-',
#   'None',
#   '1992-09-26',
#   '-',
#   '1988-04-27',
#   '-',
#   '1994-08-28',
#   'None',
#   '2002-08-06',
#   '1982-09-27',
#   'None',
#   'None',
#   '1991-12-02',
#   'None',
#   '-',
#   '-',
#   '1992',
#   'None',
#   '1995-09-05',
#   '-',
#   'None',
#   '-',
#   '1994-05-25',
#   '1980-02-12',
#   '-',
#   '1992-07-14',
#   '1997-10-24',
#   '1995-09-22',
#   '-',
#   '1993-01-10',
#   'None',
#   '1999-02-16',
#   '1994-10-15',
#   '-',
#   'None',
#   '-',
#   '1987-07-17',
#   '1998-08-08',
#   '2004-04-13',
#   '-',
#   '1984-01-30',
#   'None',
#   '1981-07-21',
#   '1996',
#   '1981-01-25',
#   'None',
#   'None',
#   '1995-02-15',
#   '1993-06-07',
#   '1997-03-03',
#   'None',
#   '1991-12-22',
#   '1992-08-02',
#   'None',
#   '-',
#   '-',
#   '1987-07-25',
#   '2003-09-28',
#   '2000-09-18',
#   'None',
#   '-',
#   '1989-03-17',
#   '1969-11-04',
#   '1928-07-17',
#   '-',
#   '-',
#   '1996-06-15',
#   '1987-07-25',
#   '-',
#   '-',
#   '1992-06-15',
#   'None',
#   '1997',
#   '-',
#   '1989-11-19',
#   '1992-08-27',
#   '-',
#   'None',
#   'None',
#   '1996-12-11',
#   '1990-11-24',
#   '-',
#   '1997-09-09',
#   'None',
#   '1991-07-02',
#   '1977-02-02',
#   '2000-09-16',
#   '-',
#   '-',
#   'None',
#   '2002-10-24',
#   '1978-11-10',
#   '-',
#   '-',
#   'None',
#   '-',
#   '1974-11-02',
#   '-',
#   '-',
#   '1980-12-31',
#   '-',
#   '1996-04-18',
#   '1997-06-14',
#   '-',
#   'None',
#   '-',
#   '1996-02-05',
#   '1985-05-29',
#   '-',
#   'None',
#   '-',
#   '1992-07-15',
#   '1991-12-16',
#   '-',
#   '-',
#   '1993-03-30',
#   '-',
#   '-',
#   '2002-11-25',
#   '-',
#   '1997-08-26',
#   '1982-09-25',
#   '1997-09-01',
#   '1997-04-27',
#   '-',
#   '1973-04-16',
#   '1998-07-08',
#   '1985-06-21',
#   '2000-11-09',
#   '1995-02-01',
#   'None',
#   'None',
#   '-',
#   '2001-06-02',
#   'None',
#   '1986-02-05',
#   '1993-05-23',
#   '1994-09-29',
#   '1980',
#   '1994-04-25',
#   '1756-01-27',
#   '1988-02-20',
#   '1991-06-12',
#   '1996-10-22',
#   '1981-01-28',
#   '1994-02-18',
#   'None',
#   '1999-06-04',
#   'None',
#   'None',
#   '1990-12-26',
#   'None',
#   '1979-09-08',
#   '1984-09-27',
#   '1991-02-17',
#   '1975-11-26',
#   '1998-02-11',
#   'None',
#   '1986-03-18',
#   'None',
#   '1994-04-15',
#   '-',
#   '1991-09-11',
#   'None',
#   '1995-01-13',
#   '1996-02-02',
#   '-',
#   '1994-08-08',
#   '1994-06-05',
#   '-',
#   '-',
#   '2002-07-13',
#   '1978-12-28',
#   '-',
#   '1988-03-08',
#   '1992-06-23',
#   '1986-12-30',
#   'None',
#   '1957-01-04',
#   '1990-11-27',
#   '1989-08-02',
#   '-',
#   '1979-09-16',
#   '1981-01-05',
#   '1994-08-17',
#   '1994-03-01',
#   '1997-05-15',
#   '-',
#   '1983-12-03',
#   '1990-03-09',
#   'None',
#   '1942-06-18',
#   'None',
#   '-',
#   'None',
#   '1998-11-01',
#   'None',
#   '-',
#   'None',
#   'None',
#   '1993-04-03',
#   '1998-02-19',
#   '1999-07-15',
#   '1975-12-18',
#   '1997-06-25',
#   '1991-09-21',
#   'None',
#   '1990-05-28',
#   '1977-05-14',
#   '1997-08-28',
#   'None',
#   '1999-04-02',
#   '1987-10-29',
#   '-',
#   '1992-07-22',
#   'None',
#   '1997-02-08',
#   'None',
#   '1995-08-24',
#   '-',
#   '-',
#   '-',
#   '1999-08-23',
#   '1992-02-10',
#   'None',
#   'None',
#   '1984-01-17',
#   '1972-08-03',
#   '1987-03-31',
#   '1998-06-26',
#   '1988-01-16',
#   '1995-09-25',
#   '-',
#   '-',
#   'None',
#   '1989-09-02',
#   '1996-05-15',
#   'None',
#   'None',
#   '2001-05-17',
#   '1982-04-24',
#   '-',
#   '-',
#   '1994-03-19',
#   'None',
#   '2000-07-09',
#   '1989-03-09',
#   'None',
#   '2000-05-28',
#   '1995-12-06',
#   '-',
#   '1947-09-21',
#   '1979-11-27',
#   '1988-03-02',
#   '2002-05-15',
#   '-',
#   'None',
#   '-',
#   '1996-12-17',
#   '-',
#   'None',
#   'None',
#   '1995-10-17',
#   '1992-03-23',
#   'None',
#   '-',
#   '1994-02-10',
#   'None',
#   '1984-01-06',
#   '1998-07-21',
#   '1992-01-11',
#   '-',
#   '1989-05-11',
#   '1979-01-18',
#   'None',
#   '1993-04-10',
#   '1988-03-17',
#   '1995-10-13',
#   'None',
#   '1977-06-22',
#   '-',
#   '1990-07-16',
#   '1685-03-21',
#   '1994-07-17',
#   '2000-06-22',
#   '2003-02-20',
#   '1984-12-04',
#   '1987-05-21',
#   '2000-11-13',
#   '1988-05-05',
#   '-',
#   'None',
#   '1985-10-08',
#   '-',
#   '1998-08-18',
#   '2011',
#   '-',
#   'None',
#   '1995-10-06',
#   '1986-06-13',
#   '1995-06-11',
#   'None',
#   '-',
#   '1994-07-04',
#   '-',
#   '1994-03-23',
#   '1998',
#   '-',
#   'None',
#   '1998-05-13',
#   '1988-08-17',
#   '1987-06-24',
#   'None',
#   'None',
#   '1995-04-05',
#   '1951-01-09',
#   '1993',
#   '1980-02-27',
#   'None',
#   '-',
#   'None',
#   '1993-11-30',
#   '1940-06-08',
#   '1999-03-05',
#   '-',
#   '1995-01-16',
#   '1997-10-10',
#   '1989-08-09',
#   'None',
#   '1991-03-30',
#   '1995-06-05',
#   '2000-10-31',
#   '1995',
#   '1989-06-10',
#   '1953-05-15',
#   '1946-09-16',
#   '1997-02-11',
#   '-',
#   '1994-02-14',
#   '1995-08-22',
#   '-',
#   '-',
#   '1987-10-29',
#   '-',
#   'None',
#   '2000-06-29',
#   '1993-06-26',
#   '-',
#   '-',
#   'None',
#   '1985-10-10',
#   '1987-04-09',
#   ...],
#  'Fecha fallecimiento': ['-',
#   None,
#   '-',
#   '-',
#   None,
#   None,
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   None,
#   None,
#   'None',
#   '-',
#   '-',
#   '-',
#   None,
#   None,
#   '-',
#   None,
#   None,
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   None,
#   '-',
#   None,
#   '-',
#   'None',
#   '-',
#   '-',
#   None,
#   None,
#   'None',
#   '-',
#   None,
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   'None',
#   '-',
#   None,
#   'None',
#   None,
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   None,
#   None,
#   '-',
#   '-',
#   '-',
#   'None',
#   None,
#   True,
#   'None',
#   None,
#   '-',
#   None,
#   None,
#   '-',
#   None,
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   'None',
#   '-',
#   None,
#   '-',
#   '-',
#   'None',
#   '-',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '-',
#   '-',
#   '-',
#   None,
#   None,
#   '-',
#   'None',
#   None,
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   'None',
#   '-',
#   '-',
#   '-',
#   None,
#   'None',
#   None,
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   None,
#   '-',
#   'None',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   'None',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   'None',
#   'None',
#   '-',
#   None,
#   None,
#   'None',
#   '-',
#   'None',
#   '-',
#   None,
#   'None',
#   None,
#   None,
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   'None',
#   'None',
#   '-',
#   None,
#   'None',
#   'None',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   None,
#   '-',
#   None,
#   None,
#   '-',
#   None,
#   None,
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   'None',
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   True,
#   None,
#   None,
#   'None',
#   '-',
#   '-',
#   '-',
#   None,
#   None,
#   '-',
#   '-',
#   None,
#   None,
#   '-',
#   None,
#   'None',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   'None',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   None,
#   None,
#   'None',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   True,
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   None,
#   None,
#   'None',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   'None',
#   '-',
#   '-',
#   None,
#   '-',
#   None,
#   '-',
#   None,
#   '-',
#   None,
#   None,
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   None,
#   True,
#   '-',
#   '-',
#   None,
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   'None',
#   '-',
#   None,
#   None,
#   '-',
#   '-',
#   '-',
#   'None',
#   '-',
#   None,
#   None,
#   'None',
#   None,
#   None,
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   True,
#   '-',
#   '-',
#   None,
#   None,
#   '-',
#   'None',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   'None',
#   'None',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   None,
#   None,
#   '-',
#   '-',
#   'None',
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   'None',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   'None',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   None,
#   '-',
#   'None',
#   '-',
#   'None',
#   'None',
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   None,
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   '-',
#   None,
#   'None',
#   '-',
#   '-',
#   '-',
#   '-',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'None',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'None',
#   None,
#   None,
#   True,
#   'None',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '-',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '-',
#   '-',
#   None,
#   'None',
#   None,
#   None,
#   'None',
#   None,
#   None,
#   'None',
#   '-',
#   '-',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'None',
#   '-',
#   None,
#   'None',
#   None,
#   'None',
#   'None',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'None',
#   'None',
#   '-',
#   'None',
#   None,
#   '-',
#   None,
#   '-',
#   None,
#   'None',
#   None,
#   None,
#   'None',
#   'None',
#   None,
#   'None',
#   '-',
#   '-',
#   None,
#   'None',
#   None,
#   '-',
#   'None',
#   '-',
#   None,
#   None,
#   '-',
#   None,
#   None,
#   None,
#   '-',
#   None,
#   'None',
#   None,
#   None,
#   '-',
#   'None',
#   '-',
#   None,
#   None,
#   None,
#   '-',
#   None,
#   'None',
#   None,
#   None,
#   None,
#   'None',
#   'None',
#   None,
#   None,
#   None,
#   'None',
#   None,
#   None,
#   'None',
#   '-',
#   '-',
#   None,
#   None,
#   None,
#   'None',
#   '-',
#   None,
#   None,
#   True,
#   '-',
#   '-',
#   None,
#   None,
#   '-',
#   '-',
#   None,
#   'None',
#   None,
#   '-',
#   None,
#   None,
#   '-',
#   'None',
#   'None',
#   None,
#   None,
#   '-',
#   None,
#   'None',
#   None,
#   None,
#   None,
#   '-',
#   '-',
#   'None',
#   None,
#   None,
#   '-',
#   '-',
#   'None',
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   None,
#   None,
#   '-',
#   'None',
#   '-',
#   None,
#   None,
#   '-',
#   'None',
#   '-',
#   None,
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   None,
#   None,
#   None,
#   None,
#   '-',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'None',
#   'None',
#   '-',
#   None,
#   'None',
#   None,
#   None,
#   None,
#   None,
#   None,
#   True,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'None',
#   None,
#   'None',
#   'None',
#   None,
#   'None',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'None',
#   None,
#   'None',
#   None,
#   '-',
#   None,
#   'None',
#   None,
#   None,
#   '-',
#   None,
#   None,
#   '-',
#   '-',
#   None,
#   None,
#   '-',
#   None,
#   None,
#   None,
#   'None',
#   None,
#   None,
#   None,
#   '-',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '-',
#   None,
#   None,
#   'None',
#   None,
#   'None',
#   '-',
#   'None',
#   None,
#   'None',
#   '-',
#   'None',
#   'None',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'None',
#   None,
#   None,
#   None,
#   'None',
#   None,
#   None,
#   '-',
#   None,
#   'None',
#   None,
#   'None',
#   None,
#   '-',
#   '-',
#   '-',
#   None,
#   None,
#   'None',
#   'None',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '-',
#   '-',
#   'None',
#   None,
#   None,
#   'None',
#   'None',
#   None,
#   None,
#   '-',
#   '-',
#   None,
#   'None',
#   None,
#   None,
#   'None',
#   None,
#   None,
#   '-',
#   None,
#   None,
#   None,
#   None,
#   '-',
#   'None',
#   '-',
#   None,
#   '-',
#   'None',
#   'None',
#   None,
#   None,
#   'None',
#   '-',
#   None,
#   'None',
#   None,
#   None,
#   None,
#   '-',
#   None,
#   None,
#   'None',
#   None,
#   None,
#   None,
#   'None',
#   None,
#   '-',
#   None,
#   True,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '-',
#   'None',
#   None,
#   '-',
#   None,
#   None,
#   '-',
#   'None',
#   None,
#   None,
#   None,
#   'None',
#   '-',
#   None,
#   '-',
#   None,
#   None,
#   '-',
#   'None',
#   None,
#   None,
#   None,
#   'None',
#   'None',
#   None,
#   None,
#   None,
#   None,
#   'None',
#   '-',
#   'None',
#   None,
#   None,
#   None,
#   '-',
#   None,
#   None,
#   None,
#   'None',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   True,
#   None,
#   '-',
#   None,
#   None,
#   '-',
#   '-',
#   None,
#   '-',
#   'None',
#   None,
#   None,
#   '-',
#   '-',
#   'None',
#   None,
#   None,
#   ...]}

# %%
df_info_artistas = pd.DataFrame(info_artistas)

df_info_artistas
# Out:
#               Nombre    Tipo País de Origen    Área de Origen  \
# 0           Måneskin   Group             IT              Roma
# 1         Elton John  Person             GB            Pinner
# 2           Parmalee   Group             US              None
# 3        OneRepublic   Group             US  Colorado Springs
# 4       Thomas Rhett  Person             US          Valdosta
# ...              ...     ...            ...               ...
# 1884   xaviersobased  Person             US          New York
# 1885    Quando Rondo  Person           None          Savannah
# 1886      Mighty Bay    None           None              None
# 1887         50 Cent  Person             US     South Jamaica
# 1888  Ralfy the Plug  Person             US       Los Angeles
#
#      Inicio de actividad Fin de actividad Fecha nacimiento Fecha fallecimiento
# 0                   2016             None                -                   -
# 1                      -                -       1947-03-25                None
# 2                   None             None                -                   -
# 3                   2004             None                -                   -
# 4                      -                -       1990-03-30                None
# ...                  ...              ...              ...                 ...
# 1884                   -                -       2003-10-23                None
# 1885                   -                -             1999                None
# 1886                   -                -             None                None
# 1887                   -                -       1975-07-06                None
# 1888                   -                -             None                None
#
# [1889 rows x 8 columns]

# %%
df_info_artistas.to_csv('musicbrainz_df_concatenado.csv')

# %%
lista_artistas = list(df_info_artistas['Nombre'].unique())

df_lista_artistas = pd.DataFrame(lista_artistas)

# %%
df_lista_artistas.to_csv('lista_artistas_musicbrainz.csv', index=False)
