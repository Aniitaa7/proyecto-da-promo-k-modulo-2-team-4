# %%
import requests

import pandas as pd
# !pip install musicbrainzngs

# %%
url = 'https://musicbrainz.org/ws/2/release/?query=*&limit=100&offset=0&fmt=json'

# %%
datos_artista = requests.get(url)
datos_artista.status_code
# Out:
# 200

# %%
artistas = datos_artista.json()
artistas
# Out:
# {'created': '2024-10-15T11:39:04.384Z',
#  'count': 4378785,
#  'offset': 0,
#  'releases': [{'id': 'de23d395-5d21-40f9-9fd8-6c7de83c4af5',
#    'score': 100,
#    'status-id': '4e304316-386d-3409-af2e-78857eec5cfe',
#    'count': 1,
#    'title': 'Man Oh Man!',
#    'status': 'Official',
#    'text-representation': {'language': 'eng', 'script': 'Latn'},
#    'artist-credit': [{'name': 'The Womenfolk',
#      'artist': {'id': 'e720d7eb-1ba2-4d9e-a45e-a8f4bcb4b49e',
#       'name': 'The Womenfolk',
#       'sort-name': 'Womenfolk, The'}}],
#    'release-group': {'id': 'ba7b360a-9cc0-4400-9ef9-2b437edc9775',
#     'type-id': 'f529b476-6e62-324f-b0aa-1f3e33d313fc',
#     'primary-type-id': 'f529b476-6e62-324f-b0aa-1f3e33d313fc',
#     'title': 'Man Oh Man!',
#     'primary-type': 'Album'},
#    'date': '1966',
#    'country': 'US',
#    'release-events': [{'date': '1966',
#      'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#       'name': 'United States',
# ...
