# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
# Configuración para poder visualizar todas las columnas de los DataFrames
pd.set_option('display.max_columns', None) 
import json

# %%
# Necesitamos el listado de artistas que sacamos en musicbrainz
# leemos el archivo csv con pandas
df_lista_artistas = pd.read_csv("lista_artistas_musicbrainz.csv")
df_lista_artistas
# Out:
#                   0
# 0          Måneskin
# 1        Elton John
# 2          Parmalee
# 3      Thomas Rhett
# 4       OneRepublic
# ...             ...
# 1880  xaviersobased
# 1881      Fetty Wap
# 1882   Ensemble JFW
# 1883  Balming Tiger
# 1884   Quando Rondo
#
# [1885 rows x 1 columns]

# %%
# hacemos una lista con el dataframe que nos devuelve
artistas = list(df_lista_artistas['0'])
artistas
# Out:
# ['Måneskin',
#  'Elton John',
#  'Parmalee',
#  'Thomas Rhett',
#  'OneRepublic',
#  'Jason Aldean',
#  'Elle King',
#  'Imagine Dragons',
#  'Duran Duran',
#  'We Are Messengers',
#  'Greta Van Fleet',
#  'Sam Hunt',
#  'twenty one pilots',
#  'Japanese Breakfast',
#  'Phil Wickham',
#  'Jameson Rodgers',
#  'Crowder',
#  'Lake Street Dive',
#  'Goth Babe',
#  'Simple Plan',
#  'Ryan Hurd',
#  'The Neighbourhood',
#  'Lauren Daigle',
#  'Glass Animals',
#  'Mitchell Tenpenny',
#  'Tommy James',
#  'Papa Roach',
#  '[Disney]',
#  'The Hip Abduction',
#  'Scotty McCreery',
#  'Old Dominion',
#  'The Wombats',
#  'Skylar Grey',
#  'The Elovaters',
#  'Mac Powell',
#  'DENM',
#  'Aimer',
#  'Paul McCartney',
#  'THE DRIVER ERA',
#  'Chase Rice',
#  'Vance Joy',
#  'Weezer',
#  'Saint Motel',
#  'MercyMe',
#  'No Vacation',
#  'Florida Georgia Line',
#  'The White Stripes',
#  'Ryan Stevenson',
#  'Rob Zombie',
#  'Bee Gees',
#  'Surfer Girl',
#  'Friday Pilots Club',
#  'Jimmie Allen',
# ...

# %%
info_artistas = {'Nombre':[],'Biografia':[], 'Listeners':[], 'Playcount':[], 'Artistas similares':[]}

# %%
#for artista in artistas:
url = f'http://www.last.fm/api/auth/?method=artist.search&artist=Cher&api_key=6266f582176f24a5f0d5a770c0c98eadI/2.0/?method=artist.search&artist=Cher&api_key=TU_CLAVE_API&format=json' 
datos_artista = requests.get(url)
print(datos_artista.status_code)
# Out:
# 200

# %% [markdown]
# ###### No consigo sacar los datos ################

# %%
datos= pd.read_json('datos_artista')
# Out:
# /tmp/ipykernel_55853/768097836.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   datos= pd.read_json('datos_artista')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 datos= pd.read_json('datos_artista')
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/json/_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/json/_json.py:1025, in JsonReader.read(self)
# ...
